# %% [markdown]
# # Error analysis
#
# We want to look into the cases that were predicted incorrectly by the lightgbm full model.
#
# Minh has already identified these cases, so we'll load those in and then check on the
#
# - pat services
# - pat lv of care
# - ESI
#
# Part II: look into cases that the simple model got right and the complex model got wrong.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# # Data
#
# Load in the data

# %%
# predicted labels
results_dir = "/home/eulalio/BMI212/2019_data/ProjectTriage/"
datadir = "/home/eulalio/BMI212/2019_data/"

label_24max_0_errors_f = "label_24max_0_errors.csv"
label_24max_1_errors_f = "label_24max_1_errors.csv"
adt_file = datadir + "traige_cohort_2019_adt.csv"
results_24hr_max_file = "lightgbm_test_results_24hr_max.csv"
csn_file = datadir + "cohort_2019_csns.csv"
all_labels_file = datadir + "triage_cohort_final_with_labels.csv"


lab0_errors = pd.read_csv(results_dir + label_24max_0_errors_f)
lab1_errors = pd.read_csv(results_dir + label_24max_1_errors_f)
adt = pd.read_csv(adt_file)
results_24hr_max = pd.read_csv(results_dir + results_24hr_max_file)
csns = pd.read_csv(csn_file)
all_labels = pd.read_csv(all_labels_file)

# %%
# mark the cns that are errors
results_24hr_max['label0_error'] = results_24hr_max.pat_enc_csn_id_coded.isin(lab0_errors.pat_enc_csn_id_coded)
results_24hr_max['label1_error'] = results_24hr_max.pat_enc_csn_id_coded.isin(lab1_errors.pat_enc_csn_id_coded)
results_24hr_max['no_error'] = ~(results_24hr_max.label0_error | results_24hr_max.label1_error)

# get more specific now
results_24hr_max['label0_no_error'] = (~results_24hr_max.label_max24) & results_24hr_max.no_error
results_24hr_max['label1_no_error'] = results_24hr_max.label_max24 & results_24hr_max.no_error

# get one column to label the error type for each csn
wide = results_24hr_max.melt(id_vars = 'pat_enc_csn_id_coded',
                             value_vars = ['label0_error', 'label1_error', 
                                           'label0_no_error', 'label1_no_error'],
                            var_name = 'error_type',
                            value_name = 'error_val',
                            )
wide = wide.drop_duplicates()

error_type = wide[wide.error_val == True]

# add it back to the original df
# results_24hr_max = results_24hr_max.merge(wide_true, how='left')

# results_24hr_max.head()
error_type.head()
# Out:
#      pat_enc_csn_id_coded    error_type  error_val
# 121          131261417339  label0_error       True
# 270          131261697536  label0_error       True
# 314          131261806170  label0_error       True
# 984          131263075650  label0_error       True
# 993          131263078470  label0_error       True

# %%
error_type.pat_enc_csn_id_coded.nunique()
# Out:
# 10096

# %%
error_type.error_type.value_counts()
# Out:
# label0_no_error    8514
# label1_no_error    1150
# label1_error        370
# label0_error         62
# Name: error_type, dtype: int64

# %%
# add the admit time column from the prediction results csv to the adt csv
adt_admit = adt.merge(error_type, how='left')
adt_admit.head()

adt_admit.columns
# Out:
# Index(['anon_id', 'pat_enc_csn_id_coded', 'pat_class', 'pat_lv_of_care',
#        'event_type', 'pat_service', 'status_of_bed', 'accomodation',
#        'effective_time_jittered_utc', 'event_time_jittered_utc',
#        'seq_num_in_enc', 'seq_num_in_bed_min', 'error_type', 'error_val'],
#       dtype='object')

# %%
# filter down to our cohort
adt_admit = adt_admit[adt_admit.pat_enc_csn_id_coded.isin(error_type.pat_enc_csn_id_coded)]

# do we still have all of the CSNs? - YES
adt_admit.pat_enc_csn_id_coded.nunique()
# Out:
# 10096

# %%
# mark the events with some labels that make things easier later
adt_admit = adt_admit.sort_values(['pat_enc_csn_id_coded', 'seq_num_in_enc'])

# **assumes dataframe is sorted by time

# mark whether previous entry had pat class Emergency Services
adt_admit['prev_emerg'] = adt_admit.pat_class.shift() == 'Emergency Services'
# mark whether current event has pat class Inpatient
adt_admit['curr_inpatient'] = adt_admit.pat_class == 'Inpatient'
# mark whether current event is continued csn as previous
adt_admit['continued'] = adt_admit.pat_enc_csn_id_coded.eq(
    adt_admit.pat_enc_csn_id_coded.shift())

# find our cases by taking the AND of these columns
cols = ['prev_emerg', 'curr_inpatient', 'continued']
adt_admit['first_ip'] = adt_admit[cols].all(axis=1)

adt_admit.head()
# Out:
#          anon_id  pat_enc_csn_id_coded           pat_class pat_lv_of_care  \
# 279178  JCe3a0de          131260430594  Emergency Services            NaN
# 279714  JCe3a0de          131260430594  Emergency Services            NaN
# 279479  JCe3a0de          131260430594  Emergency Services            NaN
# 279721  JCe3a0de          131260430594  Emergency Services            NaN
# 279700  JCe3a0de          131260430594  Emergency Services            NaN
#
#           event_type pat_service  status_of_bed accomodation  \
# 279178     Admission   Emergency            NaN        Ward
# 279714  Transfer Out   Emergency            NaN        Ward
# 279479   Transfer In   Emergency            NaN        Ward
# 279721  Transfer Out   Emergency            NaN        Ward
# 279700   Transfer In   Emergency            NaN        Ward
#
#        effective_time_jittered_utc  event_time_jittered_utc  seq_num_in_enc  \
# 279178     2019-01-01 02:47:00 UTC  2019-01-01 02:47:00 UTC               1
# 279714     2019-01-01 02:48:00 UTC  2019-01-01 02:48:00 UTC               2
# 279479     2019-01-01 02:48:00 UTC  2019-01-01 02:48:00 UTC               3
# 279721     2019-01-01 03:08:00 UTC  2019-01-01 03:08:00 UTC               4
# 279700     2019-01-01 03:08:00 UTC  2019-01-01 03:08:00 UTC               5
#
#         seq_num_in_bed_min       error_type error_val  prev_emerg  \
# 279178                 1.0  label0_no_error      True       False
# 279714                 1.0  label0_no_error      True        True
# 279479                 1.0  label0_no_error      True        True
# 279721                 1.0  label0_no_error      True        True
# 279700                 1.0  label0_no_error      True        True
#
#         curr_inpatient  continued  first_ip
# 279178           False      False     False
# 279714           False       True     False
# 279479           False       True     False
# 279721           False       True     False
# 279700           False       True     False

# %% [markdown]
# # Look at first inpatient pat services

# %%
first_ips = adt_admit[adt_admit.first_ip == True]

first_ips.pat_enc_csn_id_coded.nunique()
# Out:
# 10042

# %%
first_ips.head()

first_ips[first_ips.error_type == 'label0_error']
# Out:
#           anon_id  pat_enc_csn_id_coded  pat_class  \
# 405504   JCd54fd8          131261417339  Inpatient
# 31603    JCe2ca8e          131261697536  Inpatient
# 844225  JC2a2446e          131261806170  Inpatient
# 912997   JCe78250          131263075650  Inpatient
# 364961   JCcc01cd          131263078470  Inpatient
# ...           ...                   ...        ...
# 720564  JC2a13f4c          131279046559  Inpatient
# 711516   JCd66d08          131279504450  Inpatient
# 672489  JC2a187b0          131279506274  Inpatient
# 853565   JCd0a8db          131280941610  Inpatient
# 904960   JCe9e0c2          131281010306  Inpatient
#
#                                            pat_lv_of_care      event_type  \
# 405504       Acute Care (Assessment or intervention q4-8)  Patient Update
# 31603        Acute Care (Assessment or intervention q4-8)  Patient Update
# 844225       Acute Care (Assessment or intervention q4-8)  Patient Update
# 912997  IICU/Intermediate Care (Assessment or interven...  Patient Update
# 364961       Acute Care (Assessment or intervention q4-8)  Patient Update
# ...                                                   ...             ...
# 720564       Acute Care (Assessment or intervention q4-8)  Patient Update
# 711516       Acute Care (Assessment or intervention q4-8)  Patient Update
# 672489       Acute Care (Assessment or intervention q4-8)  Patient Update
# 853565  IICU/Intermediate Care (Assessment or interven...  Patient Update
# 904960       Acute Care (Assessment or intervention q4-8)  Patient Update
#
#                           pat_service  status_of_bed accomodation  \
# 405504                     Cardiology            NaN        Ward
# 31603                Thoracic Surgery            NaN        Ward
# 844225  General Medicine (University)            NaN        Ward
# 912997  General Medicine (University)            NaN        Ward
# 364961                      Emergency            NaN        Ward
# ...                               ...            ...          ...
# 720564            Orthopaedic Surgery            NaN        Ward
# 711516            Orthopaedic Surgery            NaN        Ward
# 672489             Emergency Medicine            NaN        Ward
# 853565  General Medicine (University)            NaN        Ward
# 904960  General Medicine (University)            NaN        Ward
#
#        effective_time_jittered_utc  event_time_jittered_utc  seq_num_in_enc  \
# 405504     2019-01-21 02:13:00 UTC  2019-01-21 02:30:00 UTC               4
# 31603      2019-01-31 08:21:00 UTC  2019-01-31 08:30:00 UTC               3
# 844225     2019-01-09 19:20:00 UTC  2019-01-09 19:23:00 UTC               8
# 912997     2019-01-03 07:59:00 UTC  2019-01-03 08:08:00 UTC               4
# 364961     2019-01-16 21:48:00 UTC  2019-01-16 21:48:00 UTC               2
# ...                            ...                      ...             ...
# 720564     2019-11-05 21:30:00 UTC  2019-11-05 22:39:00 UTC               3
# 711516     2019-12-23 04:44:00 UTC  2019-12-23 04:52:00 UTC               3
# 672489     2019-11-07 04:03:00 UTC  2019-11-07 04:03:00 UTC               3
# 853565     2019-11-28 00:11:00 UTC  2019-11-28 00:12:00 UTC               3
# 904960     2019-12-11 11:48:00 UTC  2019-12-11 11:50:00 UTC               4
#
#         seq_num_in_bed_min    error_type error_val  prev_emerg  \
# 405504                 1.0  label0_error      True        True
# 31603                  1.0  label0_error      True        True
# 844225                 1.0  label0_error      True        True
# 912997                 1.0  label0_error      True        True
# 364961                 1.0  label0_error      True        True
# ...                    ...           ...       ...         ...
# 720564                 1.0  label0_error      True        True
# 711516                 1.0  label0_error      True        True
# 672489                 1.0  label0_error      True        True
# 853565                 1.0  label0_error      True        True
# 904960                 1.0  label0_error      True        True
#
#         curr_inpatient  continued  first_ip
# 405504            True       True      True
# 31603             True       True      True
# 844225            True       True      True
# 912997            True       True      True
# 364961            True       True      True
# ...                ...        ...       ...
# 720564            True       True      True
# 711516            True       True      True
# 672489            True       True      True
# 853565            True       True      True
# 904960            True       True      True
#
# [62 rows x 18 columns]

# %%
# see a table
sorted_lab1 = first_ips.groupby(['pat_service', 'error_type']).size().unstack(fill_value=0).sort_values('label1_error', 
                                                                                          ascending=False)
sorted_lab1
# Out:
# error_type                     label0_error  label0_no_error  label1_error  \
# pat_service
# Emergency                                 9             1406           103
# Emergency Medicine                        9              896            59
# Critical Care                             0                3            46
# Cardiology                                7              527            21
# Neurosurgery                              0               83            20
# Trauma                                    5               77            19
# General Surgery                           1              460            14
# Medicine                                  8              747            13
# Neurocritical Care                        0                0            12
# General Medicine (University)            11             1309            10
# ENT                                       0               64             5
# ICU Trauma/GenSurg                        0                1             5
# Hematology                                0              134             5
# Emergency Critical Care                   0                0             4
# General Medicine (PAMF)                   1              372             4
# Pulmonary Hypertension                    0               34             4
# Pulmonary Transplant                      0               89             4
# Cardiovascular Medicine                   2               49             3
# Cardiovascular ICU                        0                2             3
# Cardiology Transplant                     0               55             3
# Gyn-Oncology                              0              126             3
# Oncology                                  1              396             2
# Neurology                                 0              112             2
# Cardiac Surgery                           1               30             2
# Hepatology                                0               75             1
# Vascular Surgery                          1               53             1
# Hematology/Oncology                       1               77             1
# Hand Surgery                              0               19             1
# Orthopaedic Surgery                       3              313             0
# Urology                                   0               49             0
# Cardiology Arrhythmia                     0                8             0
# Transplant Surgery                        0               16             0
# Thoracic Surgery                          1               33             0
# Spinal Surgery                            0                1             0
# Cardiology Congenital                     0                2             0
# Cardiology Interventional                 0                3             0
# Pulmonary                                 0                9             0
# Psychiatry                                0              443             0
# Psych Oncology                            0                1             0
# Plastic Surgery                           0               42             0
# Pain Management                           0                2             0
# Ophthalmology                             0                3             0
# Cystic Fibrosis Adult                     0               55             0
# Obstetrics                                0                2             0
# GI/Liver                                  0               51             0
# Neurology/Stroke Svc                      0               56             0
# Gastroenterology                          0               43             0
# General Medicine (T)                      0                6             0
# Nephrology                                0               23             0
# Gynecology                                1               34             0
# Liver Transplant                          0               26             0
# Kidney & Kidney/Pancreas                  0                3             0
# Interventional Radiology                  0                1             0
# Immunology                                0                1             0
# Bone Marrow Transplant                    0               39             0
#
# error_type                     label1_no_error
# pat_service
# Emergency                                  317
# Emergency Medicine                         207
# Critical Care                              205
# Cardiology                                  51
# Neurosurgery                                12
# Trauma                                      98
# General Surgery                             37
# Medicine                                    18
# Neurocritical Care                          27
# General Medicine (University)               34
# ENT                                          0
# ICU Trauma/GenSurg                          40
# Hematology                                   1
# Emergency Critical Care                     35
# General Medicine (PAMF)                      2
# Pulmonary Hypertension                       0
# Pulmonary Transplant                         4
# Cardiovascular Medicine                      3
# Cardiovascular ICU                          16
# Cardiology Transplant                        1
# Gyn-Oncology                                 2
# Oncology                                     4
# Neurology                                    2
# Cardiac Surgery                              7
# Hepatology                                   1
# Vascular Surgery                             2
# Hematology/Oncology                          1
# Hand Surgery                                 0
# Orthopaedic Surgery                          1
# Urology                                      3
# Cardiology Arrhythmia                        2
# Transplant Surgery                           0
# Thoracic Surgery                             2
# Spinal Surgery                               0
# Cardiology Congenital                        0
# Cardiology Interventional                    7
# Pulmonary                                    2
# Psychiatry                                   0
# Psych Oncology                               0
# Plastic Surgery                              0
# Pain Management                              0
# Ophthalmology                                0
# Cystic Fibrosis Adult                        0
# Obstetrics                                   0
# GI/Liver                                     0
# Neurology/Stroke Svc                         1
# Gastroenterology                             0
# General Medicine (T)                         0
# Nephrology                                   0
# Gynecology                                   0
# Liver Transplant                             1
# Kidney & Kidney/Pancreas                     0
# Interventional Radiology                     0
# Immunology                                   0
# Bone Marrow Transplant                       3

# %%
sorted_lab1['sum'] = sorted_lab1.sum(axis=1)

sorted_lab = sorted_lab1.loc[:,"label0_error":"label1_no_error"].div(sorted_lab1['sum'], axis=0) * 100

sorted_lab.sort_values('label1_error', ascending=False)
# Out:
# error_type                     label0_error  label0_no_error  label1_error  \
# pat_service
# Neurocritical Care                 0.000000         0.000000     30.769231
# Critical Care                      0.000000         1.181102     18.110236
# Neurosurgery                       0.000000        72.173913     17.391304
# Cardiovascular ICU                 0.000000         9.523810     14.285714
# ICU Trauma/GenSurg                 0.000000         2.173913     10.869565
# Pulmonary Hypertension             0.000000        89.473684     10.526316
# Emergency Critical Care            0.000000         0.000000     10.256410
# Trauma                             2.512563        38.693467      9.547739
# ENT                                0.000000        92.753623      7.246377
# Emergency                          0.490463        76.621253      5.613079
# Cardiovascular Medicine            3.508772        85.964912      5.263158
# Cardiology Transplant              0.000000        93.220339      5.084746
# Emergency Medicine                 0.768574        76.515798      5.038429
# Cardiac Surgery                    2.500000        75.000000      5.000000
# Hand Surgery                       0.000000        95.000000      5.000000
# Pulmonary Transplant               0.000000        91.752577      4.123711
# Hematology                         0.000000        95.714286      3.571429
# Cardiology                         1.155116        86.963696      3.465347
# General Surgery                    0.195312        89.843750      2.734375
# Gyn-Oncology                       0.000000        96.183206      2.290076
# Vascular Surgery                   1.754386        92.982456      1.754386
# Neurology                          0.000000        96.551724      1.724138
# Medicine                           1.017812        95.038168      1.653944
# Hepatology                         0.000000        97.402597      1.298701
# Hematology/Oncology                1.250000        96.250000      1.250000
# General Medicine (PAMF)            0.263852        98.153034      1.055409
# General Medicine (University)      0.806452        95.967742      0.733138
# Oncology                           0.248139        98.263027      0.496278
# General Medicine (T)               0.000000       100.000000      0.000000
# Obstetrics                         0.000000       100.000000      0.000000
# GI/Liver                           0.000000       100.000000      0.000000
# Neurology/Stroke Svc               0.000000        98.245614      0.000000
# Gastroenterology                   0.000000       100.000000      0.000000
# Immunology                         0.000000       100.000000      0.000000
# Nephrology                         0.000000       100.000000      0.000000
# Gynecology                         2.857143        97.142857      0.000000
# Liver Transplant                   0.000000        96.296296      0.000000
# Kidney & Kidney/Pancreas           0.000000       100.000000      0.000000
# Interventional Radiology           0.000000       100.000000      0.000000
# Ophthalmology                      0.000000       100.000000      0.000000
# Cystic Fibrosis Adult              0.000000       100.000000      0.000000
# Cardiology Interventional          0.000000        30.000000      0.000000
# Pain Management                    0.000000       100.000000      0.000000
# Plastic Surgery                    0.000000       100.000000      0.000000
# Psych Oncology                     0.000000       100.000000      0.000000
# Psychiatry                         0.000000       100.000000      0.000000
# Pulmonary                          0.000000        81.818182      0.000000
# Cardiology Congenital              0.000000       100.000000      0.000000
# Spinal Surgery                     0.000000       100.000000      0.000000
# Thoracic Surgery                   2.777778        91.666667      0.000000
# Transplant Surgery                 0.000000       100.000000      0.000000
# Cardiology Arrhythmia              0.000000        80.000000      0.000000
# Urology                            0.000000        94.230769      0.000000
# Orthopaedic Surgery                0.946372        98.738170      0.000000
# Bone Marrow Transplant             0.000000        92.857143      0.000000
#
# error_type                     label1_no_error
# pat_service
# Neurocritical Care                   69.230769
# Critical Care                        80.708661
# Neurosurgery                         10.434783
# Cardiovascular ICU                   76.190476
# ICU Trauma/GenSurg                   86.956522
# Pulmonary Hypertension                0.000000
# Emergency Critical Care              89.743590
# Trauma                               49.246231
# ENT                                   0.000000
# Emergency                            17.275204
# Cardiovascular Medicine               5.263158
# Cardiology Transplant                 1.694915
# Emergency Medicine                   17.677199
# Cardiac Surgery                      17.500000
# Hand Surgery                          0.000000
# Pulmonary Transplant                  4.123711
# Hematology                            0.714286
# Cardiology                            8.415842
# General Surgery                       7.226562
# Gyn-Oncology                          1.526718
# Vascular Surgery                      3.508772
# Neurology                             1.724138
# Medicine                              2.290076
# Hepatology                            1.298701
# Hematology/Oncology                   1.250000
# General Medicine (PAMF)               0.527704
# General Medicine (University)         2.492669
# Oncology                              0.992556
# General Medicine (T)                  0.000000
# Obstetrics                            0.000000
# GI/Liver                              0.000000
# Neurology/Stroke Svc                  1.754386
# Gastroenterology                      0.000000
# Immunology                            0.000000
# Nephrology                            0.000000
# Gynecology                            0.000000
# Liver Transplant                      3.703704
# Kidney & Kidney/Pancreas              0.000000
# Interventional Radiology              0.000000
# Ophthalmology                         0.000000
# Cystic Fibrosis Adult                 0.000000
# Cardiology Interventional            70.000000
# Pain Management                       0.000000
# Plastic Surgery                       0.000000
# Psych Oncology                        0.000000
# Psychiatry                            0.000000
# Pulmonary                            18.181818
# Cardiology Congenital                 0.000000
# Spinal Surgery                        0.000000
# Thoracic Surgery                      5.555556
# Transplant Surgery                    0.000000
# Cardiology Arrhythmia                20.000000
# Urology                               5.769231
# Orthopaedic Surgery                   0.315457
# Bone Marrow Transplant                7.142857

# %%
# plot them
plt.figure(figsize=(10,20))
p = sns.countplot(data=first_ips,
             y='pat_service',
              hue='error_type',
            order = sorted_lab1.label1_error
             )

p.set_xscale('log')
plt.title("First inpatient pat service")

plt.show()

# %%
# plot percentages
df1 = first_ips.groupby('error_type')['pat_service'].value_counts(normalize=True)
df1 = df1.mul(100)
df1 = df1.rename('percent').reset_index()

p = sns.catplot(y='pat_service',
               x='percent',
               hue='error_type',
               kind='bar',
               data=df1,
               height=15)
# p.fig.get_axes()[0].set_xscale('log')
plt.title("First inpatient pat service by Percent")

plt.show()

# %% [markdown]
# ## Look at last Emergeny Services Pat Service

# %%
# mark the events with some labels that make things easier later

# **assumes dataframe is sorted by time

# mark whether next entry is inpatient
adt_admit['next_ip'] = adt_admit.pat_class.shift(-1) == 'Inpatient'
# mark whether current event has pat class Inpatient
adt_admit['curr_emerg'] = adt_admit.pat_class == 'Emergency Services'
# mark whether current event is continued csn as previous
adt_admit['not_continued'] = ~adt_admit.pat_enc_csn_id_coded.eq(
    adt_admit.pat_enc_csn_id_coded.shift(-1))

# find our cases by taking the AND of these columns
cols = ['next_ip', 'curr_emerg', 'continued']
adt_admit['last_emerg'] = adt_admit.curr_emerg & (adt_admit.next_ip | adt_admit.not_continued) 

adt_admit[['pat_enc_csn_id_coded', 'pat_class', 'last_emerg'] + cols].head(20)
# Out:
#         pat_enc_csn_id_coded           pat_class  last_emerg  next_ip  \
# 279178          131260430594  Emergency Services       False    False
# 279714          131260430594  Emergency Services       False    False
# 279479          131260430594  Emergency Services       False    False
# 279721          131260430594  Emergency Services       False    False
# 279700          131260430594  Emergency Services       False    False
# 279264          131260430594  Emergency Services        True     True
# 405605          131260430594           Inpatient       False     True
# 405386          131260430594           Inpatient       False     True
# 405179          131260430594           Inpatient       False     True
# 405255          131260430594           Inpatient       False     True
# 405399          131260430594           Inpatient       False     True
# 405262          131260430594           Inpatient       False     True
# 405304          131260430594           Inpatient       False     True
# 405494          131260430594           Inpatient       False     True
# 405270          131260430594           Inpatient       False     True
# 405188          131260430594           Inpatient       False     True
# 405326          131260430594           Inpatient       False     True
# 405215          131260430594           Inpatient       False     True
# 405637          131260430594           Inpatient       False     True
# 405614          131260430594           Inpatient       False     True
#
#         curr_emerg  continued
# 279178        True      False
# 279714        True       True
# 279479        True       True
# 279721        True       True
# 279700        True       True
# 279264        True       True
# 405605       False       True
# 405386       False       True
# 405179       False       True
# 405255       False       True
# 405399       False       True
# 405262       False       True
# 405304       False       True
# 405494       False       True
# 405270       False       True
# 405188       False       True
# 405326       False       True
# 405215       False       True
# 405637       False       True
# 405614       False       True

# %%
last_emergs = adt_admit[adt_admit.last_emerg == True]

print(last_emergs.pat_enc_csn_id_coded.nunique())

last_emergs.head()
# Out:
# 10042
#          anon_id  pat_enc_csn_id_coded           pat_class pat_lv_of_care  \
# 279264  JCe3a0de          131260430594  Emergency Services            NaN
# 246052  JCde6879          131260494741  Emergency Services            NaN
# 234022  JCe039f4          131260628973  Emergency Services            NaN
# 297558  JCe0ef14          131260654663  Emergency Services            NaN
# 284319  JCe8c709          131260660815  Emergency Services            NaN
#
#          event_type pat_service  status_of_bed accomodation  \
# 279264       Census   Emergency            NaN        Ward
# 246052    Admission   Emergency            NaN        Ward
# 234022       Census   Emergency            NaN        Ward
# 297558  Transfer In   Emergency            NaN        Ward
# 284319    Admission   Emergency            NaN        Ward
#
#        effective_time_jittered_utc  event_time_jittered_utc  ...  \
# 279264     2019-01-01 07:59:00 UTC  2019-01-01 07:59:00 UTC  ...
# 246052     2019-01-01 20:37:00 UTC  2019-01-01 20:37:00 UTC  ...
# 234022     2019-01-01 07:59:00 UTC  2019-01-01 07:59:00 UTC  ...
# 297558     2019-01-05 21:50:00 UTC  2019-01-05 21:50:00 UTC  ...
# 284319     2018-12-31 21:24:00 UTC  2018-12-31 21:24:00 UTC  ...
#
#              error_type  error_val prev_emerg curr_inpatient  continued  \
# 279264  label0_no_error       True       True          False       True
# 246052  label0_no_error       True      False          False      False
# 234022  label0_no_error       True       True          False       True
# 297558  label1_no_error       True       True          False       True
# 284319  label0_no_error       True      False          False      False
#
#         first_ip  next_ip  curr_emerg  not_continued  last_emerg
# 279264     False     True        True          False        True
# 246052     False     True        True          False        True
# 234022     False     True        True          False        True
# 297558     False     True        True          False        True
# 284319     False     True        True          False        True
#
# [5 rows x 22 columns]

# %%
adt_admit.error_type.value_counts()
# Out:
# label0_no_error    161222
# label1_no_error     26511
# label1_error         8429
# label0_error         1481
# Name: error_type, dtype: int64

# %%
last_emergs.error_type.value_counts()
# Out:
# label0_no_error    8461
# label1_no_error    1149
# label1_error        370
# label0_error         62
# Name: error_type, dtype: int64

# %%
# see a table
last_emergs.groupby(['pat_service', 'error_type']).size().unstack(fill_value=0).sort_values('label0_no_error', 
                                                                                          ascending=False)
# Out:
# error_type               label0_error  label0_no_error  label1_error  \
# pat_service
# Emergency                          37             5092           233
# Emergency Medicine                 25             3362           137
# Medicine                            0                4             0
# General Surgery                     0                1             0
# Neurosurgery                        0                1             0
# Trauma                              0                1             0
# Cardiovascular Medicine             0                0             0
#
# error_type               label1_no_error
# pat_service
# Emergency                            661
# Emergency Medicine                   486
# Medicine                               0
# General Surgery                        0
# Neurosurgery                           0
# Trauma                                 1
# Cardiovascular Medicine                1

# %%
# plot them
plt.figure(figsize=(10,20))
p = sns.countplot(data=last_emergs,
             y='pat_service',
              hue='error_type',
            order = first_ips.pat_service.value_counts().index
             )

p.set_xscale('log')
plt.title("Last ED pat service")

plt.show()

# %%
# plot percentages
df1 = last_emergs.groupby('error_type')['pat_service'].value_counts(normalize=True)
df1 = df1.mul(100)
df1 = df1.rename('percent').reset_index()

p = sns.catplot(y='pat_service',
               x='percent',
               hue='error_type',
               kind='bar',
               data=df1,
               height=15)
# p.fig.get_axes()[0].set_xscale('log')
plt.title("Last ED pat service by Percent")

plt.show()

# %% [markdown]
# # Pat lv of care
#
# Look at pat lv of care when patients are admitted

# %%
adt_admit.columns
# Out:
# Index(['anon_id', 'pat_enc_csn_id_coded', 'pat_class', 'pat_lv_of_care',
#        'event_type', 'pat_service', 'status_of_bed', 'accomodation',
#        'effective_time_jittered_utc', 'event_time_jittered_utc',
#        'seq_num_in_enc', 'seq_num_in_bed_min', 'error_type', 'error_val',
#        'prev_emerg', 'curr_inpatient', 'continued', 'first_ip', 'next_ip',
#        'curr_emerg', 'not_continued', 'last_emerg'],
#       dtype='object')

# %%
results_24hr_max.columns
# Out:
# Index(['Unnamed: 0', 'anon_id', 'pat_enc_csn_id_coded',
#        'inpatient_data_id_coded', 'label_max24', 'admit_time', 'admit_label',
#        'label_24hr_recent', 'label_12hr_recent', 'has_admit_label',
#        'first_label', 'first_label_time_since_admit',
#        'acute_to_critical_label', 'critical_to_acute_label', 'label',
#        'predictions', 'label0_error', 'label1_error', 'no_error',
#        'label0_no_error', 'label1_no_error'],
#       dtype='object')

# %%
# we only want inpatient events after the admission time

# add the admit time
adt_results = adt_admit.merge(all_labels[['pat_enc_csn_id_coded', 'admit_time']], how='left')
adt_results.columns
# Out:
# Index(['anon_id', 'pat_enc_csn_id_coded', 'pat_class', 'pat_lv_of_care',
#        'event_type', 'pat_service', 'status_of_bed', 'accomodation',
#        'effective_time_jittered_utc', 'event_time_jittered_utc',
#        'seq_num_in_enc', 'seq_num_in_bed_min', 'error_type', 'error_val',
#        'prev_emerg', 'curr_inpatient', 'continued', 'first_ip', 'next_ip',
#        'curr_emerg', 'not_continued', 'last_emerg', 'admit_time'],
#       dtype='object')

# %%
# change admit time and effective time to datetime - these take a littl while to run!!

# change the effective time to datetime since read in from csv
adt_results.effective_time_jittered_utc = pd.to_datetime(adt_results.effective_time_jittered_utc)

# change admit time
adt_results.admit_time = pd.to_datetime(adt_results.admit_time)

# %%
# filter down to 24hrs after admit
adt_results['time_since_admit'] = adt_results.effective_time_jittered_utc - adt_results.admit_time

adt_results_24hr = adt_results[adt_results.time_since_admit < timedelta(hours=24)]

adt_results_24hr.head()
# Out:
#     anon_id  pat_enc_csn_id_coded           pat_class pat_lv_of_care  \
# 0  JCe3a0de          131260430594  Emergency Services            NaN
# 1  JCe3a0de          131260430594  Emergency Services            NaN
# 2  JCe3a0de          131260430594  Emergency Services            NaN
# 3  JCe3a0de          131260430594  Emergency Services            NaN
# 4  JCe3a0de          131260430594  Emergency Services            NaN
#
#      event_type pat_service  status_of_bed accomodation  \
# 0     Admission   Emergency            NaN        Ward
# 1  Transfer Out   Emergency            NaN        Ward
# 2   Transfer In   Emergency            NaN        Ward
# 3  Transfer Out   Emergency            NaN        Ward
# 4   Transfer In   Emergency            NaN        Ward
#
#   effective_time_jittered_utc  event_time_jittered_utc  ...  prev_emerg  \
# 0   2019-01-01 02:47:00+00:00  2019-01-01 02:47:00 UTC  ...       False
# 1   2019-01-01 02:48:00+00:00  2019-01-01 02:48:00 UTC  ...        True
# 2   2019-01-01 02:48:00+00:00  2019-01-01 02:48:00 UTC  ...        True
# 3   2019-01-01 03:08:00+00:00  2019-01-01 03:08:00 UTC  ...        True
# 4   2019-01-01 03:08:00+00:00  2019-01-01 03:08:00 UTC  ...        True
#
#    curr_inpatient continued first_ip  next_ip  curr_emerg  not_continued  \
# 0           False     False    False    False        True          False
# 1           False      True    False    False        True          False
# 2           False      True    False    False        True          False
# 3           False      True    False    False        True          False
# 4           False      True    False    False        True          False
#
#    last_emerg                admit_time  time_since_admit
# 0       False 2019-01-01 09:19:00+00:00 -1 days +17:28:00
# 1       False 2019-01-01 09:19:00+00:00 -1 days +17:29:00
# 2       False 2019-01-01 09:19:00+00:00 -1 days +17:29:00
# 3       False 2019-01-01 09:19:00+00:00 -1 days +17:49:00
# 4       False 2019-01-01 09:19:00+00:00 -1 days +17:49:00
#
# [5 rows x 24 columns]

# %%
# filter to inpatient events after admit time
ip_events = adt_results_24hr[(adt_results_24hr.admit_time <= adt_results_24hr.effective_time_jittered_utc) &
                     (adt_results_24hr.pat_class == 'Inpatient')]

ip_events.pat_enc_csn_id_coded.nunique()
# Out:
# 10096

# %%
# keep only change of lv of care status

# sort by sequence 
ip_events = ip_events.sort_values(['pat_enc_csn_id_coded', 'seq_num_in_enc'])

# keep only those that change
change_care = ip_events[~(ip_events.pat_lv_of_care.eq(ip_events.pat_lv_of_care.shift()) &
                         ip_events.pat_enc_csn_id_coded.eq(ip_events.pat_enc_csn_id_coded.shift()))]

change_care.pat_enc_csn_id_coded.nunique()
# Out:
# 10096

# %%
change_care.size
# Out:
# 279744

# %%
change_care[change_care.pat_enc_csn_id_coded.eq(change_care.shift().pat_enc_csn_id_coded)].head()
# Out:
#       anon_id  pat_enc_csn_id_coded  pat_class  \
# 123  JCd25448          131260687489  Inpatient
# 141  JCe7730f          131260730304  Inpatient
# 142  JCe7730f          131260730304  Inpatient
# 365  JCd68a92          131260806868  Inpatient
# 548  JCea699c          131260852330  Inpatient
#
#                                         pat_lv_of_care      event_type  \
# 123       Acute Care (Assessment or intervention q4-8)  Patient Update
# 141       Acute Care (Assessment or intervention q4-8)  Patient Update
# 142  IICU/Intermediate Care (Assessment or interven...  Patient Update
# 365                                      Critical Care  Patient Update
# 548  IICU/Intermediate Care (Assessment or interven...  Patient Update
#
#                pat_service  status_of_bed   accomodation  \
# 123                 Trauma            NaN          Ward
# 141          Critical Care            NaN  Semi-Private
# 142          Critical Care            NaN  Semi-Private
# 365  Cardiology Transplant            NaN        Private
# 548             Hepatology            NaN          Ward
#
#     effective_time_jittered_utc  event_time_jittered_utc  ...  prev_emerg  \
# 123   2019-01-05 11:13:00+00:00  2019-01-05 11:13:00 UTC  ...       False
# 141   2019-01-05 19:06:00+00:00  2019-01-05 19:06:00 UTC  ...       False
# 142   2019-01-05 21:26:00+00:00  2019-01-05 21:26:00 UTC  ...       False
# 365   2019-01-05 01:43:00+00:00  2019-01-05 01:43:00 UTC  ...       False
# 548   2019-01-08 01:49:00+00:00  2019-01-08 01:49:00 UTC  ...       False
#
#      curr_inpatient continued first_ip  next_ip  curr_emerg  not_continued  \
# 123            True      True    False     True       False          False
# 141            True      True    False     True       False          False
# 142            True      True    False     True       False          False
# 365            True      True    False     True       False          False
# 548            True      True    False     True       False          False
#
#      last_emerg                admit_time  time_since_admit
# 123       False 2019-01-05 09:45:00+00:00   0 days 01:28:00
# 141       False 2019-01-05 03:09:00+00:00   0 days 15:57:00
# 142       False 2019-01-05 03:09:00+00:00   0 days 18:17:00
# 365       False 2019-01-04 20:10:00+00:00   0 days 05:33:00
# 548       False 2019-01-08 01:13:00+00:00   0 days 00:36:00
#
# [5 rows x 24 columns]

# %%
trajectory = change_care[['pat_enc_csn_id_coded', 'pat_lv_of_care']].groupby('pat_enc_csn_id_coded').agg(
{'pat_lv_of_care' : lambda x: ' -> '.join([str(c) for c in x])}).reset_index().rename({'pat_lv_of_care': 'care_trajectory'}, axis=1)

# %%
# join to the change care df again
ip_traj = trajectory.merge(ip_events[['pat_enc_csn_id_coded', 'error_type']], how='left').drop_duplicates()

# %%
ip_traj.columns
# Out:
# Index(['pat_enc_csn_id_coded', 'care_trajectory', 'error_type'], dtype='object')

# %%
counts = ip_traj.groupby(['error_type', 'pat_enc_csn_id_coded']).care_trajectory.value_counts().groupby(['error_type', 'care_trajectory']).describe()

# %%
traj_count = ip_traj.groupby(['error_type']).agg(traj_count=pd.NamedAgg(column='care_trajectory', aggfunc='value_counts')).reset_index().sort_values(['error_type', 'traj_count'], ascending=False)

traj_count
# Out:
#          error_type                                    care_trajectory  \
# 43  label1_no_error                                      Critical Care
# 44  label1_no_error  Critical Care -> Acute Care (Assessment or int...
# 45  label1_no_error  Acute Care (Assessment or intervention q4-8) -...
# 46  label1_no_error  Critical Care -> IICU/Intermediate Care (Asses...
# 47  label1_no_error  IICU/Intermediate Care (Assessment or interven...
# ..              ...                                                ...
# 1      label0_error  IICU/Intermediate Care (Assessment or interven...
# 2      label0_error  IICU/Intermediate Care (Assessment or interven...
# 3      label0_error  Acute Care (Assessment or intervention q4-8) -...
# 4      label0_error  Acute Care (Assessment or intervention q4-8) -...
# 5      label0_error  nan -> Acute Care (Assessment or intervention ...
#
#     traj_count
# 43         650
# 44         231
# 45          72
# 46          65
# 47          25
# ..         ...
# 1           12
# 2            7
# 3            2
# 4            1
# 5            1
#
# [70 rows x 3 columns]

# %%
traj_count_sub = traj_count.groupby('error_type').head(10)

traj_count_sub.to_csv("/home/eulalio/BMI212/2019_data/cohort_2019_care_trajectories.csv",
                     sep="\t", index=False)

# %%
traj_count_sub
# Out:
#          error_type                                    care_trajectory  \
# 43  label1_no_error                                      Critical Care
# 44  label1_no_error  Critical Care -> Acute Care (Assessment or int...
# 45  label1_no_error  Acute Care (Assessment or intervention q4-8) -...
# 46  label1_no_error  Critical Care -> IICU/Intermediate Care (Asses...
# 47  label1_no_error  IICU/Intermediate Care (Assessment or interven...
# 48  label1_no_error  Critical Care -> IICU/Intermediate Care (Asses...
# 49  label1_no_error  Acute Care (Assessment or intervention q4-8) -...
# 50  label1_no_error                               nan -> Critical Care
# 51  label1_no_error  Acute Care (Assessment or intervention q4-8) -...
# 52  label1_no_error  Critical Care -> Acute Care (Assessment or int...
# 23     label1_error                                      Critical Care
# 24     label1_error  Acute Care (Assessment or intervention q4-8) -...
# 25     label1_error  Critical Care -> Acute Care (Assessment or int...
# 26     label1_error  Acute Care (Assessment or intervention q4-8) -...
# 27     label1_error  Critical Care -> IICU/Intermediate Care (Asses...
# 28     label1_error  IICU/Intermediate Care (Assessment or interven...
# 29     label1_error  Acute Care (Assessment or intervention q4-8) -...
# 30     label1_error  Acute Care (Assessment or intervention q4-8) -...
# 31     label1_error  Acute Care (Assessment or intervention q4-8) -...
# 32     label1_error  Critical Care -> Acute Care (Assessment or int...
# 6   label0_no_error       Acute Care (Assessment or intervention q4-8)
# 7   label0_no_error  IICU/Intermediate Care (Assessment or interven...
# 8   label0_no_error  Acute Care (Assessment or intervention q4-8) -...
# 9   label0_no_error  IICU/Intermediate Care (Assessment or interven...
# 10  label0_no_error  Acute Care (Assessment or intervention q4-8) -...
# 11  label0_no_error  nan -> Acute Care (Assessment or intervention ...
# 12  label0_no_error  IICU/Intermediate Care (Assessment or interven...
# 13  label0_no_error  nan -> nan -> nan -> Acute Care (Assessment or...
# 14  label0_no_error  Acute Care (Assessment or intervention q4-8) -...
# 15  label0_no_error  nan -> IICU/Intermediate Care (Assessment or i...
# 0      label0_error       Acute Care (Assessment or intervention q4-8)
# 1      label0_error  IICU/Intermediate Care (Assessment or interven...
# 2      label0_error  IICU/Intermediate Care (Assessment or interven...
# 3      label0_error  Acute Care (Assessment or intervention q4-8) -...
# 4      label0_error  Acute Care (Assessment or intervention q4-8) -...
# 5      label0_error  nan -> Acute Care (Assessment or intervention ...
#
#     traj_count
# 43         650
# 44         231
# 45          72
# 46          65
# 47          25
# 48          23
# 49          18
# 50          12
# 51           9
# 52           9
# 23         143
# 24          87
# 25          67
# 26          16
# 27          15
# 28          14
# 29           9
# 30           3
# 31           2
# 32           2
# 6         7620
# 7          339
# 8          257
# 9          154
# 10          82
# 11          39
# 12           7
# 13           4
# 14           3
# 15           2
# 0           39
# 1           12
# 2            7
# 3            2
# 4            1
# 5            1

# %% [markdown]
# # Part II: Model disagreement
#
# Looking into cases that the simple model got right and the complex model got wrong.
#
# Defined as:
# - lgbm24max < 0.4
# - preds_24max > 0.55
# - diff24max > 0.2
#
# Should be about 32 of them
#
# Check out pat servies
