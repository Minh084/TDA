# %% [markdown]
# # Length of stay in ED
#
# Look at the length of stay in emergency department for all cases.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy import stats

# %%
# adjust this to hide ID columns for posting to github
forrepo=False

hidecols = []
if forrepo:
    hidecols=['anon_id', 'pat_enc_csn_id_coded', 'inpatient_data_id_coded'] # these are hidden columns

# %%
# read in data files
datadir = "../../DataTD/"
resultsdir = "../../OutputTD/3_models/1_4_cohort_24hrpreadmit/"

adt_file = datadir + "cohort_1_3_adt.csv"
results_file = resultsdir + "1_4_cohort_test_results.csv"
cohort_file = "../../OutputTD/1_cohort/1_4_cohort.csv"


full_adt = pd.read_csv(adt_file)
results = pd.read_csv(results_file)
cohort = pd.read_csv(cohort_file)
# Out:
# /home/eulalio/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# filter down to csns in our cohort
adt = full_adt[full_adt.pat_enc_csn_id_coded.isin(cohort.pat_enc_csn_id_coded)]

adt.pat_enc_csn_id_coded.nunique()
# Out:
# 43980

# %%
# csns in our test cohort
results.pat_enc_csn_id_coded.nunique()
# Out:
# 12418

# %% [markdown]
# # Format data
#
# Convert datetime columns to the correct format.

# %%
adt.columns
# Out:
# Index(['anon_id', 'pat_enc_csn_id_coded', 'effective_time_jittered_utc',
#        'seq_num_in_enc', 'pat_class', 'base_pat_class_c', 'pat_lvl_of_care_c',
#        'pat_lv_of_care', 'event_type', 'pat_service'],
#       dtype='object')

# %%
# add year of admit
adt['effective_year'] = pd.DatetimeIndex(adt['effective_time_jittered_utc']).year
adt.drop(hidecols, axis=1, errors='ignore').head()
# Out:
# <ipython-input-7-f2107e62f907>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adt['effective_year'] = pd.DatetimeIndex(adt['effective_time_jittered_utc']).year
#   effective_time_jittered_utc  seq_num_in_enc           pat_class  \
# 0     2019-10-31 10:46:00 UTC               4           Inpatient
# 1     2020-01-17 22:12:00 UTC               3           Inpatient
# 2     2019-12-06 07:22:00 UTC               6           Inpatient
# 3     2017-10-08 06:59:00 UTC               2  Emergency Services
# 4     2015-04-02 06:59:00 UTC               2  Emergency Services
#
#    base_pat_class_c  pat_lvl_of_care_c             pat_lv_of_care  \
# 0               1.0               66.0     Neonatal ICU - VC Only
# 1               1.0               68.0  Newborn Nursery - VC Only
# 2               1.0               68.0  Newborn Nursery - VC Only
# 3               NaN                NaN                        NaN
# 4               NaN                NaN                        NaN
#
#        event_type         pat_service  effective_year
# 0  Patient Update  Emergency Medicine            2019
# 1  Patient Update  Emergency Medicine            2020
# 2  Patient Update           Emergency            2019
# 3          Census           Emergency            2017
# 4          Census           Emergency            2015

# %%
# ** takes a long time to run **

# change the effective time to datetime since read in from csv
adt.effective_time_jittered_utc = pd.to_datetime(adt.effective_time_jittered_utc)
# Out:
# /home/eulalio/.local/lib/python3.8/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# add the admit time column from the prediction results csv to the adt csv
admit_time = cohort[['pat_enc_csn_id_coded', 'admit_time']]

adt_admit = adt.merge(admit_time, how='left')
adt.head()

adt_admit.admit_time = pd.to_datetime(adt_admit.admit_time, utc=True)

adt_admit.columns
# Out:
# Index(['anon_id', 'pat_enc_csn_id_coded', 'effective_time_jittered_utc',
#        'seq_num_in_enc', 'pat_class', 'base_pat_class_c', 'pat_lvl_of_care_c',
#        'pat_lv_of_care', 'event_type', 'pat_service', 'effective_year',
#        'admit_time'],
#       dtype='object')

# %%
# do we still have all of the CSNs? - YES
adt_admit.pat_enc_csn_id_coded.nunique()
# Out:
# 43980

# %%
adt_admit.drop(hidecols, axis=1, errors='ignore').head()
# Out:
#   effective_time_jittered_utc  seq_num_in_enc           pat_class  \
# 0   2019-10-31 10:46:00+00:00               4           Inpatient
# 1   2020-01-17 22:12:00+00:00               3           Inpatient
# 2   2019-12-06 07:22:00+00:00               6           Inpatient
# 3   2017-10-08 06:59:00+00:00               2  Emergency Services
# 4   2015-04-02 06:59:00+00:00               2  Emergency Services
#
#    base_pat_class_c  pat_lvl_of_care_c             pat_lv_of_care  \
# 0               1.0               66.0     Neonatal ICU - VC Only
# 1               1.0               68.0  Newborn Nursery - VC Only
# 2               1.0               68.0  Newborn Nursery - VC Only
# 3               NaN                NaN                        NaN
# 4               NaN                NaN                        NaN
#
#        event_type         pat_service  effective_year  \
# 0  Patient Update  Emergency Medicine            2019
# 1  Patient Update  Emergency Medicine            2020
# 2  Patient Update           Emergency            2019
# 3          Census           Emergency            2017
# 4          Census           Emergency            2015
#
#                  admit_time
# 0 2019-10-31 10:46:00+00:00
# 1 2020-01-17 22:12:00+00:00
# 2 2019-12-06 07:22:00+00:00
# 3 2017-10-08 07:59:00+00:00
# 4 2015-04-02 11:07:00+00:00

# %%
# compute the time before admit for each of these events
adt_admit['time_before_admit'] = adt_admit.apply(lambda x: x.admit_time - x.effective_time_jittered_utc, axis=1)
adt_admit.drop(hidecols, axis=1, errors='ignore').head()
# Out:
#   effective_time_jittered_utc  seq_num_in_enc           pat_class  \
# 0   2019-10-31 10:46:00+00:00               4           Inpatient
# 1   2020-01-17 22:12:00+00:00               3           Inpatient
# 2   2019-12-06 07:22:00+00:00               6           Inpatient
# 3   2017-10-08 06:59:00+00:00               2  Emergency Services
# 4   2015-04-02 06:59:00+00:00               2  Emergency Services
#
#    base_pat_class_c  pat_lvl_of_care_c             pat_lv_of_care  \
# 0               1.0               66.0     Neonatal ICU - VC Only
# 1               1.0               68.0  Newborn Nursery - VC Only
# 2               1.0               68.0  Newborn Nursery - VC Only
# 3               NaN                NaN                        NaN
# 4               NaN                NaN                        NaN
#
#        event_type         pat_service  effective_year  \
# 0  Patient Update  Emergency Medicine            2019
# 1  Patient Update  Emergency Medicine            2020
# 2  Patient Update           Emergency            2019
# 3          Census           Emergency            2017
# 4          Census           Emergency            2015
#
#                  admit_time time_before_admit
# 0 2019-10-31 10:46:00+00:00   0 days 00:00:00
# 1 2020-01-17 22:12:00+00:00   0 days 00:00:00
# 2 2019-12-06 07:22:00+00:00   0 days 00:00:00
# 3 2017-10-08 07:59:00+00:00   0 days 01:00:00
# 4 2015-04-02 11:07:00+00:00   0 days 04:08:00

# %% [markdown]
# We want to find the length of stay in the ED, so we'll add some columns to help figure out which ADT events mark the admission to Emergency services and transfer to Inpatient.
#
# We're looking for:
#
# - the first Inpatient event that follow Emergency Services (should be admit time)
# - the first Emergency Services event

# %%
# mark the events with some labels that make things easier later

# sort by csn and time
adt_admit.sort_values(['pat_enc_csn_id_coded', 'seq_num_in_enc'], inplace=True)


# **assumes dataframe is sorted by time

# the first inpatient event following Emergency Services must meet these three criteria:
    # mark whether previous entry had pat class Emergency Services
adt_admit['prev_emerg'] = adt_admit.pat_class.shift() == 'Emergency Services'
    # mark whether current event has pat class Inpatient
adt_admit['curr_inpatient'] = adt_admit.pat_class == 'Inpatient'
    # mark whether current event is continued csn as previous
adt_admit['continued'] = adt_admit.pat_enc_csn_id_coded.eq(
    adt_admit.pat_enc_csn_id_coded.shift())

# find our cases by taking the AND of these columns
cols = ['prev_emerg', 'curr_inpatient', 'continued']
adt_admit['first_ip'] = adt_admit[cols].all(axis=1)

adt_admit.drop(hidecols, axis=1, errors='ignore').head()
# Out:
#         anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 19178  JCe78a06          131062667066   2015-01-01 17:10:00+00:00
# 19438  JCe78a06          131062667066   2015-01-02 00:32:00+00:00
# 19096  JCe78a06          131062667066   2015-01-02 00:32:00+00:00
# 19434  JCe78a06          131062667066   2015-01-02 00:49:00+00:00
# 19100  JCe78a06          131062667066   2015-01-02 00:49:00+00:00
#
#        seq_num_in_enc           pat_class  base_pat_class_c  \
# 19178               1  Emergency Services               3.0
# 19438               2  Emergency Services               NaN
# 19096               3  Emergency Services               NaN
# 19434               4  Emergency Services               NaN
# 19100               5  Emergency Services               NaN
#
#        pat_lvl_of_care_c pat_lv_of_care    event_type pat_service  \
# 19178                NaN            NaN     Admission   Emergency
# 19438                NaN            NaN  Transfer Out   Emergency
# 19096                NaN            NaN   Transfer In   Emergency
# 19434                NaN            NaN  Transfer Out   Emergency
# 19100                NaN            NaN   Transfer In   Emergency
#
#        effective_year                admit_time time_before_admit  prev_emerg  \
# 19178            2015 2015-01-02 01:01:00+00:00   0 days 07:51:00       False
# 19438            2015 2015-01-02 01:01:00+00:00   0 days 00:29:00        True
# 19096            2015 2015-01-02 01:01:00+00:00   0 days 00:29:00        True
# 19434            2015 2015-01-02 01:01:00+00:00   0 days 00:12:00        True
# 19100            2015 2015-01-02 01:01:00+00:00   0 days 00:12:00        True
#
#        curr_inpatient  continued  first_ip
# 19178           False      False     False
# 19438           False       True     False
# 19096           False       True     False
# 19434           False       True     False
# 19100           False       True     False

# %% [markdown]
# Find the first emergency services pat_class for each csn.

# %%
# start by taking events that have a different pat class from the next event (below it)
change_pat = adt_admit[~adt_admit.pat_class.eq(adt_admit.pat_class.shift())]
change_pat.drop(hidecols, axis=1, errors='ignore').head()
# Out:
#          anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 19178   JCe78a06          131062667066   2015-01-01 17:10:00+00:00
# 217107  JCe78a06          131062667066   2015-01-02 01:01:00+00:00
# 33      JCd1c19e          131062745090   2015-01-03 01:56:00+00:00
# 294639  JCd1c19e          131062745090   2015-01-03 05:53:00+00:00
# 77116   JCd91eb2          131062747648   2015-01-01 01:10:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 19178                1  Emergency Services               3.0
# 217107               7           Inpatient               1.0
# 33                   1  Emergency Services               3.0
# 294639               9           Inpatient               1.0
# 77116                1  Emergency Services               3.0
#
#         pat_lvl_of_care_c                                pat_lv_of_care  \
# 19178                 NaN                                           NaN
# 217107                6.0      Intermediate Care - With Cardiac Monitor
# 33                    NaN                                           NaN
# 294639                5.0  Acute Care (Assessment or intervention q4-8)
# 77116                 NaN                                           NaN
#
#          event_type              pat_service  effective_year  \
# 19178     Admission                Emergency            2015
# 217107  Transfer In  General Medicine (PAMF)            2015
# 33        Admission                Emergency            2015
# 294639  Transfer In      Orthopaedic Surgery            2015
# 77116     Admission                Emergency            2015
#
#                       admit_time time_before_admit  prev_emerg  \
# 19178  2015-01-02 01:01:00+00:00   0 days 07:51:00       False
# 217107 2015-01-02 01:01:00+00:00   0 days 00:00:00        True
# 33     2015-01-03 05:53:00+00:00   0 days 03:57:00       False
# 294639 2015-01-03 05:53:00+00:00   0 days 00:00:00        True
# 77116  2015-01-01 08:24:00+00:00   0 days 07:14:00       False
#
#         curr_inpatient  continued  first_ip
# 19178            False      False     False
# 217107            True       True      True
# 33               False      False     False
# 294639            True       True      True
# 77116            False      False     False

# %%
# lots of these still have many events - meaning they moved around a lot
change_pat.groupby('pat_enc_csn_id_coded').anon_id.count().value_counts()
# Out:
# 2    42609
# 3      872
# 4      452
# 5       31
# 6       12
# 1        2
# 8        2
# Name: anon_id, dtype: int64

# %%
# keep the event with pat_class == Emergency Services, that occurs before the first inpatient event
# check to make sure that we're looking at the same CSN between both events
# don't take any where admit ocurred before ER event - happens when people move around a lot (ER -> Inpatient -> ER -> Inpatient)
keep_visits = change_pat[(change_pat.pat_class == 'Emergency Services') & 
                         (change_pat.shift(-1).first_ip) &
                         (change_pat.shift(-1).pat_enc_csn_id_coded == change_pat.pat_enc_csn_id_coded) & 
                         (change_pat.time_before_admit >= timedelta(days=0))] # remove this for now
keep_visits.drop(hidecols, axis=1, errors='ignore').head()
# Out:
#        effective_time_jittered_utc  seq_num_in_enc           pat_class  \
# 19178    2015-01-01 17:10:00+00:00               1  Emergency Services
# 33       2015-01-03 01:56:00+00:00               1  Emergency Services
# 77116    2015-01-01 01:10:00+00:00               1  Emergency Services
# 4729     2015-01-01 17:07:00+00:00               1  Emergency Services
# 109340   2015-01-04 18:13:00+00:00               1  Emergency Services
#
#         base_pat_class_c  pat_lvl_of_care_c pat_lv_of_care event_type  \
# 19178                3.0                NaN            NaN  Admission
# 33                   3.0                NaN            NaN  Admission
# 77116                3.0                NaN            NaN  Admission
# 4729                 3.0                NaN            NaN  Admission
# 109340               3.0                NaN            NaN  Admission
#
#        pat_service  effective_year                admit_time  \
# 19178    Emergency            2015 2015-01-02 01:01:00+00:00
# 33       Emergency            2015 2015-01-03 05:53:00+00:00
# 77116    Emergency            2015 2015-01-01 08:24:00+00:00
# 4729     Emergency            2015 2015-01-01 23:39:00+00:00
# 109340   Emergency            2015 2015-01-05 02:23:00+00:00
#
#        time_before_admit  prev_emerg  curr_inpatient  continued  first_ip
# 19178    0 days 07:51:00       False           False      False     False
# 33       0 days 03:57:00       False           False      False     False
# 77116    0 days 07:14:00       False           False      False     False
# 4729     0 days 06:32:00       False           False      False     False
# 109340   0 days 08:10:00       False           False      False     False

# %%
# look at the number of csn's that were dropped becuase admit time was before first ER event
print(change_pat.pat_enc_csn_id_coded.nunique())

print(keep_visits.pat_enc_csn_id_coded.nunique())

# we lose csns where admit occurs before the first ER - lost 2
# Out:
# 43980
# 43978

# %%
# compute the time lapse between the ER visit and admission in hours
keep_visits['hours_before_admit'] = keep_visits.time_before_admit / np.timedelta64(1, 'h')
keep_visits.drop(hidecols, axis=1, errors='ignore').head()
# Out:
# <ipython-input-20-368242fbd5b0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keep_visits['hours_before_admit'] = keep_visits.time_before_admit / np.timedelta64(1, 'h')
#        effective_time_jittered_utc  seq_num_in_enc           pat_class  \
# 19178    2015-01-01 17:10:00+00:00               1  Emergency Services
# 33       2015-01-03 01:56:00+00:00               1  Emergency Services
# 77116    2015-01-01 01:10:00+00:00               1  Emergency Services
# 4729     2015-01-01 17:07:00+00:00               1  Emergency Services
# 109340   2015-01-04 18:13:00+00:00               1  Emergency Services
#
#         base_pat_class_c  pat_lvl_of_care_c pat_lv_of_care event_type  \
# 19178                3.0                NaN            NaN  Admission
# 33                   3.0                NaN            NaN  Admission
# 77116                3.0                NaN            NaN  Admission
# 4729                 3.0                NaN            NaN  Admission
# 109340               3.0                NaN            NaN  Admission
#
#        pat_service  effective_year                admit_time  \
# 19178    Emergency            2015 2015-01-02 01:01:00+00:00
# 33       Emergency            2015 2015-01-03 05:53:00+00:00
# 77116    Emergency            2015 2015-01-01 08:24:00+00:00
# 4729     Emergency            2015 2015-01-01 23:39:00+00:00
# 109340   Emergency            2015 2015-01-05 02:23:00+00:00
#
#        time_before_admit  prev_emerg  curr_inpatient  continued  first_ip  \
# 19178    0 days 07:51:00       False           False      False     False
# 33       0 days 03:57:00       False           False      False     False
# 77116    0 days 07:14:00       False           False      False     False
# 4729     0 days 06:32:00       False           False      False     False
# 109340   0 days 08:10:00       False           False      False     False
#
#         hours_before_admit
# 19178             7.850000
# 33                3.950000
# 77116             7.233333
# 4729              6.533333
# 109340            8.166667

# %% [markdown]
# # Now look at time in ED

# %%
# print(keep_visits.columns)

print(keep_visits.hours_before_admit.describe())

keep_visits['hours_before_admit_quantile'] = pd.qcut(keep_visits.hours_before_admit, 10)
# Out:
# count    43979.000000
# mean         4.865520
# std          6.459111
# min          0.000000
# 25%          2.250000
# 50%          3.500000
# 75%          5.350000
# max        190.433333
# Name: hours_before_admit, dtype: float64
# <ipython-input-21-5f0033c6c3f0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keep_visits['hours_before_admit_quantile'] = pd.qcut(keep_visits.hours_before_admit, 10)

# %%
print(keep_visits.columns)

# grab the year from the admit time
keep_visits['test_set'] = keep_visits.pat_enc_csn_id_coded.isin(results.pat_enc_csn_id_coded)

keep_visits.drop(hidecols, axis=1, errors='ignore').head()
# Out:
# Index(['anon_id', 'pat_enc_csn_id_coded', 'effective_time_jittered_utc',
#        'seq_num_in_enc', 'pat_class', 'base_pat_class_c', 'pat_lvl_of_care_c',
#        'pat_lv_of_care', 'event_type', 'pat_service', 'effective_year',
#        'admit_time', 'time_before_admit', 'prev_emerg', 'curr_inpatient',
#        'continued', 'first_ip', 'hours_before_admit',
#        'hours_before_admit_quantile'],
#       dtype='object')
# <ipython-input-22-15ec4b1adf5f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keep_visits['test_set'] = keep_visits.pat_enc_csn_id_coded.isin(results.pat_enc_csn_id_coded)
#        effective_time_jittered_utc  seq_num_in_enc           pat_class  \
# 19178    2015-01-01 17:10:00+00:00               1  Emergency Services
# 33       2015-01-03 01:56:00+00:00               1  Emergency Services
# 77116    2015-01-01 01:10:00+00:00               1  Emergency Services
# 4729     2015-01-01 17:07:00+00:00               1  Emergency Services
# 109340   2015-01-04 18:13:00+00:00               1  Emergency Services
#
#         base_pat_class_c  pat_lvl_of_care_c pat_lv_of_care event_type  \
# 19178                3.0                NaN            NaN  Admission
# 33                   3.0                NaN            NaN  Admission
# 77116                3.0                NaN            NaN  Admission
# 4729                 3.0                NaN            NaN  Admission
# 109340               3.0                NaN            NaN  Admission
#
#        pat_service  effective_year                admit_time  \
# 19178    Emergency            2015 2015-01-02 01:01:00+00:00
# 33       Emergency            2015 2015-01-03 05:53:00+00:00
# 77116    Emergency            2015 2015-01-01 08:24:00+00:00
# 4729     Emergency            2015 2015-01-01 23:39:00+00:00
# 109340   Emergency            2015 2015-01-05 02:23:00+00:00
#
#        time_before_admit  prev_emerg  curr_inpatient  continued  first_ip  \
# 19178    0 days 07:51:00       False           False      False     False
# 33       0 days 03:57:00       False           False      False     False
# 77116    0 days 07:14:00       False           False      False     False
# 4729     0 days 06:32:00       False           False      False     False
# 109340   0 days 08:10:00       False           False      False     False
#
#         hours_before_admit hours_before_admit_quantile  test_set
# 19178             7.850000               (5.95, 8.133]     False
# 33                3.950000                (3.5, 4.117]     False
# 77116             7.233333               (5.95, 8.133]     False
# 4729              6.533333               (5.95, 8.133]     False
# 109340            8.166667            (8.133, 190.433]     False

# %%
# visualize distribution
p = sns.displot(keep_visits,
               x='hours_before_admit',
                hue = 'test_set'
               )
p.fig.suptitle("Distribution of time spent in ED")
p.fig.get_axes()[0].set_yscale('log')
plt.show()

# %%
# look at time spent in ED for train and test sets
keep_visits.groupby('test_set').hours_before_admit.describe()
# Out:
#             count      mean       std       min       25%  50%       75%  \
# test_set
# False     31560.0  5.208861  7.141008  0.016667  2.250000  3.6  5.666667
# True      12419.0  3.992999  4.134481  0.000000  2.233333  3.3  4.716667
#
#                  max
# test_set
# False     190.433333
# True       95.100000

# %%
# look at time spent in ED for entire cohort
keep_visits.hours_before_admit.describe()
# Out:
# count    43979.000000
# mean         4.865520
# std          6.459111
# min          0.000000
# 25%          2.250000
# 50%          3.500000
# 75%          5.350000
# max        190.433333
# Name: hours_before_admit, dtype: float64

# %%
keep_visits.drop(hidecols, axis=1, errors='ignore').head()
# Out:
#          anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 19178   JCe78a06          131062667066   2015-01-01 17:10:00+00:00
# 33      JCd1c19e          131062745090   2015-01-03 01:56:00+00:00
# 77116   JCd91eb2          131062747648   2015-01-01 01:10:00+00:00
# 4729    JCe7cb4d          131062788358   2015-01-01 17:07:00+00:00
# 109340  JCe293de          131063044001   2015-01-04 18:13:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 19178                1  Emergency Services               3.0
# 33                   1  Emergency Services               3.0
# 77116                1  Emergency Services               3.0
# 4729                 1  Emergency Services               3.0
# 109340               1  Emergency Services               3.0
#
#         pat_lvl_of_care_c pat_lv_of_care event_type pat_service  \
# 19178                 NaN            NaN  Admission   Emergency
# 33                    NaN            NaN  Admission   Emergency
# 77116                 NaN            NaN  Admission   Emergency
# 4729                  NaN            NaN  Admission   Emergency
# 109340                NaN            NaN  Admission   Emergency
#
#         effective_year                admit_time time_before_admit  \
# 19178             2015 2015-01-02 01:01:00+00:00   0 days 07:51:00
# 33                2015 2015-01-03 05:53:00+00:00   0 days 03:57:00
# 77116             2015 2015-01-01 08:24:00+00:00   0 days 07:14:00
# 4729              2015 2015-01-01 23:39:00+00:00   0 days 06:32:00
# 109340            2015 2015-01-05 02:23:00+00:00   0 days 08:10:00
#
#         prev_emerg  curr_inpatient  continued  first_ip  hours_before_admit  \
# 19178        False           False      False     False            7.850000
# 33           False           False      False     False            3.950000
# 77116        False           False      False     False            7.233333
# 4729         False           False      False     False            6.533333
# 109340       False           False      False     False            8.166667
#
#        hours_before_admit_quantile  test_set
# 19178                (5.95, 8.133]     False
# 33                    (3.5, 4.117]     False
# 77116                (5.95, 8.133]     False
# 4729                 (5.95, 8.133]     False
# 109340            (8.133, 190.433]     False

# %%
# save the hours before 
final_visits = keep_visits[['pat_enc_csn_id_coded', 'hours_before_admit']]

final_visits.rename({'hours_before_admit': 'hours_in_ed'}, axis=1, inplace=True)

print(final_visits.shape)
print(final_visits.pat_enc_csn_id_coded.nunique())

final_visits.drop(hidecols, axis=1, errors='ignore').head()
# Out:
# (43979, 2)
# 43978
# /home/eulalio/.local/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#         pat_enc_csn_id_coded  hours_in_ed
# 19178           131062667066     7.850000
# 33              131062745090     3.950000
# 77116           131062747648     7.233333
# 4729            131062788358     6.533333
# 109340          131063044001     8.166667

# %%
savedir = "../../OutputTD/4_results_analysis/"
savefile = savedir + "01_length_of_stay_in_ED.csv"

final_visits.to_csv(savefile, index=False)
