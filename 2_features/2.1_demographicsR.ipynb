# %% [markdown]
# ## Descriptions:
# process variables from demograhics table
# - Process language --> English: yes/no
# - Process insurance (medicare/caid/cal/mcal/mcare/na) --> yes/no
#
# **Inputs**:
# - *cohort1_criteria*: updated cohort0 with inc/exc criteria
# - *demographics*
#
# **Outputs**:

# %%
library(caret) # import this before glmnet to avoid rlang version problem
library(xgboost)
library(data.table)
library(tidyverse)
library(lubridate)
library(Matrix)
# library(slam)
library(glmnet)
library(bit64)
# library(mtools) for one hot coder, not available on Nero or use caret or tidyr
library(mice)
options(repr.matrix.max.rows=200, repr.matrix.max.cols=30)
# Out:
# Loading required package: lattice
#
# Loading required package: ggplot2
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ tibble  3.1.2     ✔ dplyr   1.0.6
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::between()   masks data.table::between()
# ✖ dplyr::filter()    masks stats::filter()
# ✖ dplyr::first()     masks data.table::first()
# ✖ dplyr::lag()       masks stats::lag()
# ✖ dplyr::last()      masks data.table::last()
# ✖ purrr::lift()      masks caret::lift()
# ✖ dplyr::slice()     masks xgboost::slice()
# ✖ purrr::transpose() masks data.table::transpose()
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union
#
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
#
#
# Loaded glmnet 4.1-1
#
# Loading required package: bit
#
#
# Attaching package: ‘bit’
#
#
# The following object is masked from ‘package:data.table’:
#
#     setattr
#
#
# The following object is masked from ‘package:base’:
#
#     xor
#
#
# Attaching package bit64
#
# package:bit64 (c) 2011-2017 Jens Oehlschlaegel
#
# creators: integer64 runif64 seq :
#
# coercion: as.integer64 as.vector as.logical as.integer as.double as.character as.bitstring
#
# logical operator: ! & | xor != == < <= >= >
#
# arithmetic operator: + - * / %/% %% ^
#
# math: sign abs sqrt log log2 log10
#
# math: floor ceiling trunc round
#
# querying: is.integer64 is.vector [is.atomic} [length] format print str
#
# values: is.na is.nan is.finite is.infinite
#
# aggregation: any all min max range sum prod
#
# cumulation: diff cummin cummax cumsum cumprod
#
# access: length<- [ [<- [[ [[<-
#
# combine: c rep cbind rbind as.data.frame
#
# WARNING don't use as subscripts
#
# WARNING semantics differ from integer
#
# for more help type ?bit64
#
#
# Attaching package: ‘bit64’
#
#
# The following objects are masked from ‘package:base’:
#
#     :, %in%, is.double, match, order, rank
#
#
#
# Attaching package: ‘mice’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following objects are masked from ‘package:base’:
#
#     cbind, rbind

# %% [markdown]
# ### Demographic variables
# - Age (only >=18): done in in/ex criteria
# - insurance = Medical/care/caid and n/a insurance --> medis =1 otherwise 0
# - language --> Engl = 1 for English, otherwise 0
# - leave height and weight to be processed with flowsheet age (>=18 only)

# %%
datadir = "../../DataTD"

cohort_demo <- read.csv(file.path(datadir, "cohort1_criteria.csv"))
nrow(cohort_demo)
summary(cohort_demo)
# Out:
# [1] 45986
#    anon_id          pat_enc_csn_id_coded     label        admit_time
#  Length:45986       Min.   :1.311e+11    Min.   :0.000   Length:45986
#  Class :character   1st Qu.:1.312e+11    1st Qu.:0.000   Class :character
#  Mode  :character   Median :1.312e+11    Median :0.000   Mode  :character
#                     Mean   :1.312e+11    Mean   :0.138
#                     3rd Qu.:1.313e+11    3rd Qu.:0.000
#                     Max.   :1.313e+11    Max.   :1.000
#
#  inpatient_data_id_coded      ESI        hosp_admsn_time      ed_time_hr
#  Min.   :13616753        Min.   :1.000   Length:45986       Min.   :  0.000
#  1st Qu.:19863571        1st Qu.:2.000   Class :character   1st Qu.:  2.217
#  Median :27889292        Median :3.000   Mode  :character   Median :  3.483
#  Mean   :28152729        Mean   :2.655                      Mean   :  5.015
#  3rd Qu.:34369529        3rd Qu.:3.000                      3rd Qu.:  5.367
#  Max.   :48026130        Max.   :5.000                      Max.   :190.433
#                          NA's   :1861
#     gender              race             language         recent_height_cm
#  Length:45986       Length:45986       Length:45986       Min.   : 12.95
#  Class :character   Class :character   Class :character   1st Qu.:160.02
#  Mode  :character   Mode  :character   Mode  :character   Median :167.64
#                                                           Mean   :167.97
#                                                           3rd Qu.:175.26
#                                                           Max.   :210.82
#                                                           NA's   :1420
#  recent_weight_kg  insurance         recent_date             age
#  Min.   :  0.10   Length:45986       Length:45986       Min.   :18.00
#  1st Qu.: 60.90   Class :character   Class :character   1st Qu.:44.00
#  Median : 73.10   Mode  :character   Mode  :character   Median :60.00
#  Mean   : 76.61                                         Mean   :58.28
#  3rd Qu.: 88.00                                         3rd Qu.:73.00
#  Max.   :320.69                                         Max.   :90.00
#  NA's   :311

# %%
head(cohort_demo, n=1)
# Out:
#   anon_id  pat_enc_csn_id_coded label admit_time
# 1 JCcb7792 131236214276         1     2017-06-23 22:27:00+00:00
#   inpatient_data_id_coded ESI hosp_admsn_time           ed_time_hr gender race
# 1 25347698                2   2017-06-23 20:59:00+00:00 1.466667   Female White
#   language recent_height_cm recent_weight_kg insurance recent_date age
# 1 English  NA               NA               CIGNA     2020-03-03  62

# %%
cohort_demo <- cohort_demo %>% 
                mutate(admit_time = ymd_hms(admit_time), hosp_admsn_time = ymd_hms(hosp_admsn_time), recent_date = ymd(recent_date), 
                       gender = factor(gender), race = factor(race), language = factor(language), insurance = factor(insurance))
nrow(cohort_demo)
summary(cohort_demo)
# Out:
# [1] 45986
#    anon_id          pat_enc_csn_id_coded     label
#  Length:45986       Min.   :1.311e+11    Min.   :0.000
#  Class :character   1st Qu.:1.312e+11    1st Qu.:0.000
#  Mode  :character   Median :1.312e+11    Median :0.000
#                     Mean   :1.312e+11    Mean   :0.138
#                     3rd Qu.:1.313e+11    3rd Qu.:0.000
#                     Max.   :1.313e+11    Max.   :1.000
#
#    admit_time                  inpatient_data_id_coded      ESI
#  Min.   :2015-01-01 08:24:00   Min.   :13616753        Min.   :1.000
#  1st Qu.:2016-05-22 19:15:45   1st Qu.:19863571        1st Qu.:2.000
#  Median :2017-12-31 03:18:00   Median :27889292        Median :3.000
#  Mean   :2017-10-13 04:34:25   Mean   :28152729        Mean   :2.655
#  3rd Qu.:2019-02-19 03:23:45   3rd Qu.:34369529        3rd Qu.:3.000
#  Max.   :2020-03-31 07:00:00   Max.   :48026130        Max.   :5.000
#                                                        NA's   :1861
#  hosp_admsn_time                 ed_time_hr         gender
#  Min.   :2015-01-01 01:10:00   Min.   :  0.000   Female:21997
#  1st Qu.:2016-05-22 15:19:30   1st Qu.:  2.217   Male  :23989
#  Median :2017-12-31 00:06:30   Median :  3.483
#  Mean   :2017-10-12 23:33:31   Mean   :  5.015
#  3rd Qu.:2019-02-18 23:11:15   3rd Qu.:  5.367
#  Max.   :2020-03-31 07:00:00   Max.   :190.433
#
#                race             language     recent_height_cm recent_weight_kg
#  Asian           : 6906   English   :38767   Min.   : 12.95   Min.   :  0.10
#  Black           : 3279   Spanish   : 3688   1st Qu.:160.02   1st Qu.: 60.90
#  Native American :  194   Mandarin  :  748   Median :167.64   Median : 73.10
#  Other           :10554   Vietnamese:  511   Mean   :167.97   Mean   : 76.61
#  Pacific Islander:  943   Cantonese :  265   3rd Qu.:175.26   3rd Qu.: 88.00
#  Unknown         :  426   Russian   :  264   Max.   :210.82   Max.   :320.69
#  White           :23684   (Other)   : 1743   NA's   :1420     NA's   :311
#        insurance      recent_date              age
#  MEDICARE   :17032   Min.   :2019-01-01   Min.   :18.00
#  BLUE CROSS : 3404   1st Qu.:2019-01-01   1st Qu.:44.00
#  HPSM       : 3141   Median :2020-03-11   Median :60.00
#             : 2737   Mean   :2019-10-29   Mean   :58.28
#  MEDI-CAL   : 2067   3rd Qu.:2020-03-31   3rd Qu.:73.00
#  BLUE SHIELD: 1900   Max.   :2020-03-31   Max.   :90.00
#  (Other)    :15705   NA's   :10

# %%
# checking duplicates
nrow(cohort_demo %>% select(anon_id) %>% distinct()) # 30073
nrow(cohort_demo %>% select(anon_id, pat_enc_csn_id_coded) %>% distinct()) # 43524
cohort_demo[duplicated(cohort_demo[, c('anon_id','pat_enc_csn_id_coded')]),]

# cohort_demo %>% filter(anon_id == "JCd49287") # pat_enc_csn_id_coded = 131195706986, 
# cohort_demo <- cohort_demo %>% filter (!(anon_id == "JCd49287" & race == "Unknown"))
# Out:
# [1] 31584
# [1] 45986
#      anon_id pat_enc_csn_id_coded label admit_time inpatient_data_id_coded ESI
#      hosp_admsn_time ed_time_hr gender race language recent_height_cm
#      recent_weight_kg insurance recent_date age

# %%
summary(cohort_demo %>% select(ESI, gender, race, recent_height_cm, recent_weight_kg, age))
cohort_demo %>% gather(var, value) %>% distinct() %>% count(var) %>% arrange(n)
cohort_demo %>% summarise_each(funs(n_distinct))
# Out:
#       ESI           gender                    race       recent_height_cm
#  Min.   :1.000   Female:21997   Asian           : 6906   Min.   : 12.95
#  1st Qu.:2.000   Male  :23989   Black           : 3279   1st Qu.:160.02
#  Median :3.000                  Native American :  194   Median :167.64
#  Mean   :2.655                  Other           :10554   Mean   :167.97
#  3rd Qu.:3.000                  Pacific Islander:  943   3rd Qu.:175.26
#  Max.   :5.000                  Unknown         :  426   Max.   :210.82
#  NA's   :1861                   White           :23684   NA's   :1420
#  recent_weight_kg      age
#  Min.   :  0.10   Min.   :18.00
#  1st Qu.: 60.90   1st Qu.:44.00
#  Median : 73.10   Median :60.00
#  Mean   : 76.61   Mean   :58.28
#  3rd Qu.: 88.00   3rd Qu.:73.00
#  Max.   :320.69   Max.   :90.00
#  NA's   :311
# Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”
#    var                     n
# 1  gender                      2
# 2  label                       2
# 3  ESI                         6
# 4  race                        7
# 5  language                   55
# 6  age                        73
# 7  insurance                 134
# 8  recent_date               457
# 9  recent_height_cm          790
# 10 ed_time_hr               2076
# 11 recent_weight_kg         3448
# 12 anon_id                 31584
# 13 admit_time              45451
# 14 hosp_admsn_time         45473
# 15 inpatient_data_id_coded 45986
# 16 pat_enc_csn_id_coded    45986
# Warning message:
# “`summarise_each_()` was deprecated in dplyr 0.7.0.
# Please use `across()` instead.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”
# Warning message:
# “`funs()` was deprecated in dplyr 0.8.0.
# Please use a list of either functions or lambdas:
#
#   # Simple named list:
#   list(mean = mean, median = median)
#
#   # Auto named with `tibble::lst()`:
#   tibble::lst(mean, median)
#
#   # Using lambdas
#   list(~ mean(., trim = .2), ~ median(., na.rm = TRUE))
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”
#   anon_id pat_enc_csn_id_coded label admit_time inpatient_data_id_coded ESI
# 1 31584   45986                2     45451      45986                   6
#   hosp_admsn_time ed_time_hr gender race language recent_height_cm
# 1 45473           2076       2      7    55       790
#   recent_weight_kg insurance recent_date age
# 1 3448             134       457         73

# %% [markdown]
# ### Insurance:

# %%
options(repr.matrix.max.rows=135, repr.matrix.max.cols=20)
cohort_demo %>%                 # filter(!is.na(col)) %>% filter out all rows with NAs in col 
                group_by(insurance) %>% count() %>% arrange(desc(n))
# Out:
#     insurance                                         n
# 1   MEDICARE                                          17032
# 2   BLUE CROSS                                         3404
# 3   HPSM                                               3141
# 4                                                      2737
# 5   MEDI-CAL                                           2067
# 6   BLUE SHIELD                                        1900
# 7   SANTA CLARA FAMILY HP                              1752
# 8   UNITED HEALTHCARE                                  1581
# 9   AETNA                                              1230
# 10  HPSM - MCARE ADV                                   1046
# 11  BLUE CARD (OUT OF STATE)                            982
# 12  CIGNA                                               952
# 13  HEALTHNET                                           701
# 14  MCAL HMO - CENTRAL CALIFORNIA ALLIANCE FOR HEALTH   690
# 15  ALAMEDA ALLIANCE MCAL MGD CARE                      656
# 16  UNITED HEALTHCARE SR ADV                            421
# 17  BLUE CROSS MEDI-CAL                                 419
# 18  UHC MEDICARE AARP COMPLETE                          388
# 19  SCFHP - MCARE ADV                                   368
# 20  BLUE CARD (OUT OF STATE) - BS                       329
# 21  SNF HOSPICE MEDICARE (HOSP ONLY)                    324
# 22  HEALTHNET SENIOR ADVANTAGE                          316
# 23  AETNA CHOICE POS II SHC                             248
# 24  UMR                                                 234
# 25  COMMERCIAL OTHER                                    203
# 26  VETERANS ADMINISTRATION                             198
# 27  MEDICARE SENIOR ADVANTAGE - OTHER                   193
# 28  MEDI-CAL MANAGED CARE                               184
# 29  MCAL HP OF SAN JOAQUIN                              172
# 30  PHP OF CA                                           157
# 31  KAISER                                              109
# 32  VALLEY HEALTH PLAN                                  109
# 33  AARP                                                103
# 34  TRICARE HEALTH NET                                  102
# 35  TRIWEST                                              89
# 36  MANAGED CARE OTHER                                   86
# 37  MCAL HMO-HEALTHNET                                   85
# 38  BLUE CROSS SENIOR                                    83
# 39  MEDICAID                                             80
# 40  MCAL CONTRA COSTA HEALTH PLAN                        74
# 41  UNITEDHEALTHCARE WEST                                71
# 42  ALIGNMENT HEALTHPLAN                                 63
# 43  HUMANA GOLD CHOICE                                   63
# 44  AETNA SENIOR                                         61
# 45  MCAL CENCAL                                          56
# 46  MCAL HMO-SAN FRANCISCO HEALTH PLN                    47
# 47  FIRST HEALTH                                         39
# 48  KAISER SENIOR                                        36
# 49  MULTIPLAN                                            34
# 50  MEDI-CAL CCS                                         31
# 51  VISION SERVICES PLAN                                 31
# 52  WORKERS COMP - OTHER                                 31
# 53  ZZZTRICARE UHC M AND V                               27
# 54  MEDI-CAL ONE TIME DISCOUNT                           26
# 55  PATHWAYS (HOSPITAL ONLY)                             24
# 56  PRIVATE HEALTHCARE SYS (PHCS)                        22
# 57  SUTTER HEALTH PLUS                                   20
# 58  SUTTER HEALTH SYSTEM                                 20
# 59  BSCA PROMISE HEALTH SR ADV                           19
# 60  CAREMORE ANTHEM SR ADV                               18
# 61  TRICARE FOR LIFE                                     15
# 62  GOV-OTHER                                            13
# 63  HUMANA CHOICE CARE                                   13
# 64  MEDI-CAL MGD CARE COUNTY                             12
# 65  U.S. BEHAVIORAL HEALTH                               12
# 66  INTERNATIONAL                                        11
# 67  MCAL KAISER OAKLAND                                  10
# 68  MUTUAL OF OMAHA                                      10
# 69  BENEFIT RISK MGMT                                     9
# 70  UNITED HEALTH CARE                                    9
# 71  BRAND NEW DAY SR ADV                                  8
# 72  COM-OTHER                                             8
# 73  HOMETOWN HEALTH PLAN                                  8
# 74  HOMETOWN HP SENIOR                                    8
# 75  OPTUM HEALTH/URN                                      8
# 76  MCAL HMO-MOLINA                                       7
# 77  VITALITY HEALTH PLAN SR ADV                           7
# 78  AETNA SHC ALLIANCE                                    6
# 79  ASPIRE HEALTH PLAN SR ADV                             6
# 80  CA DEPT OF CORRECTIONS                                6
# 81  CHAMPVA                                               6
# 82  MANAGED HEALTH NETWORK                                6
# 83  WORKERS COMP - STATE COMP                             6
# 84  BLUE CARD SR ADV (OUT OF STATE) - BS                  5
# 85  BLUE CARD SR ADV (OUT OF STATE) - BX                  4
# 86  INTERPLAN                                             4
# 87  MCAL KAISER SANTA CLARA                               4
# 88  UHC MEDICARE AARP COMPLETE PPO                        4
# 89  WORKERS COMP - TRAVELERS INS                          4
# 90  BLUE CARD-BX/BS OUT-OF-STATE                          3
# 91  BLUE DIST CTR FOR TRANSPLANT                          3
# 92  COVENTRY HEALTH CARE                                  3
# 93  EMPLOYER BASED PAYOR                                  3
# 94  HEALTH NET                                            3
# 95  MCAL CALOPTIMA                                        3
# 96  MCAL KAISER HAYWARD                                   3
# 97  MEDICAID HMO                                          3
# 98  PENDING INSURANCE                                     3
# 99  SCAN HEALTH PLAN                                      3
# 100 WORKERS COMP - ZURICH (SU EMP)                        3
# 101 AETNA SUTTER HEALTH                                   2
# 102 GOLDEN STATE MHP                                      2
# 103 MEDICAID OUT OF STATE                                 2
# 104 NETWORKS BY DESIGN                                    2
# 105 WORKERS COMP - FARMERS INS                            2
# 106 WORKERS COMP - MATRIX                                 2
# 107 CCS HEALTH PLAN SAN MATEO                             1
# 108 COUNTY CORRECTIONS                                    1
# 109 DONOR NETWORK WEST                                    1
# 110 GEHA                                                  1
# 111 HEALTHY FAMILIES                                      1
# 112 HEALTHY KIDS                                          1
# 113 HPSM - CCS                                            1
# 114 JOHN MUIR                                             1
# 115 MC AETNA COMM AFMG                                    1
# 116 NORTHERN NEVADA TRUST FUND                            1
# 117 OPTUM                                                 1
# 118 PHYSICIANS FOUNDATION                                 1
# 119 SAMARITAN CHOICE PLAN                                 1
# 120 SHCA COMM AETNA                                       1
# 121 THE SEQUOIAS                                          1
# 122 USA MANAGED CARE SENIOR                               1
# 123 VICTIM VIOLENT CRIME                                  1
# 124 WORKERS COMP - AIG/CHARTIS                            1
# 125 WORKERS COMP - ATHENS                                 1
# 126 WORKERS COMP - CITY/CNTY S.F.                         1
# 127 WORKERS COMP - ESIS                                   1
# 128 WORKERS COMP - GALLAGHER BSET                         1
# 129 WORKERS COMP - INNOV CARE SYS                         1
# 130 WORKERS COMP - LIBERTY MUTUAL                         1
# 131 WORKERS COMP - REPUBLIC INDEMN                        1
# 132 WORKERS COMP - US DEPT OF ENERGY-OWCP                 1
# 133 ZZZALAMEDA ALLIANCE MEDICARE ADV-                     1
# 134 ZZZWORKERS COMP - CORVEL                              1

# %%
# medi--- and no insurance
cohort_demo %>% filter(str_detect(insurance, "MEDI") | insurance == "") %>% 
                group_by(insurance) %>% count() %>% arrange(-n)

# mcal = medical, mcare = medicare
medis <- c("MEDI", "MCAL", "MCARE")
cohort_demo %>% filter(str_detect(insurance, paste(medis, collapse = "|")) | insurance == "") %>% 
                group_by(insurance) %>% count() %>% arrange(-n)
# Out:
#    insurance                         n
# 1  MEDICARE                          17032
# 2                                     2737
# 3  MEDI-CAL                           2067
# 4  BLUE CROSS MEDI-CAL                 419
# 5  UHC MEDICARE AARP COMPLETE          388
# 6  SNF HOSPICE MEDICARE (HOSP ONLY)    324
# 7  MEDICARE SENIOR ADVANTAGE - OTHER   193
# 8  MEDI-CAL MANAGED CARE               184
# 9  MEDICAID                             80
# 10 MEDI-CAL CCS                         31
# 11 MEDI-CAL ONE TIME DISCOUNT           26
# 12 MEDI-CAL MGD CARE COUNTY             12
# 13 UHC MEDICARE AARP COMPLETE PPO        4
# 14 MEDICAID HMO                          3
# 15 MEDICAID OUT OF STATE                 2
# 16 ZZZALAMEDA ALLIANCE MEDICARE ADV-     1
#    insurance                                         n
# 1  MEDICARE                                          17032
# 2                                                     2737
# 3  MEDI-CAL                                           2067
# 4  HPSM - MCARE ADV                                   1046
# 5  MCAL HMO - CENTRAL CALIFORNIA ALLIANCE FOR HEALTH   690
# 6  ALAMEDA ALLIANCE MCAL MGD CARE                      656
# 7  BLUE CROSS MEDI-CAL                                 419
# 8  UHC MEDICARE AARP COMPLETE                          388
# 9  SCFHP - MCARE ADV                                   368
# 10 SNF HOSPICE MEDICARE (HOSP ONLY)                    324
# 11 MEDICARE SENIOR ADVANTAGE - OTHER                   193
# 12 MEDI-CAL MANAGED CARE                               184
# 13 MCAL HP OF SAN JOAQUIN                              172
# 14 MCAL HMO-HEALTHNET                                   85
# 15 MEDICAID                                             80
# 16 MCAL CONTRA COSTA HEALTH PLAN                        74
# 17 MCAL CENCAL                                          56
# 18 MCAL HMO-SAN FRANCISCO HEALTH PLN                    47
# 19 MEDI-CAL CCS                                         31
# 20 MEDI-CAL ONE TIME DISCOUNT                           26
# 21 MEDI-CAL MGD CARE COUNTY                             12
# 22 MCAL KAISER OAKLAND                                  10
# 23 MCAL HMO-MOLINA                                       7
# 24 MCAL KAISER SANTA CLARA                               4
# 25 UHC MEDICARE AARP COMPLETE PPO                        4
# 26 MCAL CALOPTIMA                                        3
# 27 MCAL KAISER HAYWARD                                   3
# 28 MEDICAID HMO                                          3
# 29 MEDICAID OUT OF STATE                                 2
# 30 ZZZALAMEDA ALLIANCE MEDICARE ADV-                     1

# %%
# turn insurance into medis which has "MEDI" under insurance
# 0 for medis and no insurance, 1 for other insurance
medis <- c("MEDI", "MCAL", "MCARE")

nrow(cohort_demo %>% filter(insurance == "")) # 2737
nrow(cohort_demo %>% filter(str_detect(insurance, "MEDI"))) # 20766
nrow(cohort_demo %>% filter(str_detect(insurance, paste(medis, collapse = "|")))) # 23987

cohort_demo <- cohort_demo %>%
                    mutate(insurance = ifelse(str_detect(insurance, paste(medis, collapse = "|")) | insurance == "", 0, 1)) %>%
                    group_by(anon_id, pat_enc_csn_id_coded) %>%
                    mutate(insurance = sum(insurance)) %>% ungroup() %>% # just to make sure if anyone else has more than 1
                    mutate(insurance = ifelse(insurance>0, 1, insurance)) 

cohort_demo %>% count(insurance)
# Out:
# [1] 2737
# [1] 20766
# [1] 23987
#   insurance n
# 1 0         26724
# 2 1         19262

# %% [markdown]
# ### Language:

# %%
cohort_demo %>% group_by(language) %>% count() %>% arrange(desc(n))
# Out:
#    language               n
# 1  English                38767
# 2  Spanish                 3688
# 3  Mandarin                 748
# 4  Vietnamese               511
# 5  Cantonese                265
# 6  Russian                  264
# 7  Farsi                    262
# 8  Tongan                   219
# 9  Tagalog                  178
# 10 Korean                   152
# 11 Other                    136
# 12 Hindi                    113
# 13 Punjabi (Panjabi)        100
# 14 Dari                      82
# 15 Arabic                    66
# 16 Japanese                  51
# 17 Unknown                   40
# 18 Portuguese                35
# 19 Samoan                    32
# 20 Burmese                   25
# 21 Deaf/Non-Sign Language    22
# 22                           20
# 23 French                    20
# 24 Italian                   19
# 25 Urdu                      19
# 26 American Sign Language    17
# 27 Cambodian, Mon-Khmer      13
# 28 Polish                    12
# 29 Greek                     10
# 30 Gujarati                  10
# 31 Persian                   10
# 32 Telugu                    10
# 33 Hebrew                     8
# 34 Hmong                      8
# 35 Albanian                   7
# 36 Romanian                   7
# 37 Indonesian                 6
# 38 Laotian                    6
# 39 Armenian                   5
# 40 Traditional Chinese        4
# 41 Croatian                   2
# 42 Hindu                      2
# 43 Mien (lu Mien)             2
# 44 Thai                       2
# 45 Amharic                    1
# 46 Bosnian                    1
# 47 canadian french            1
# 48 Creole, French             1
# 49 Fijian                     1
# 50 German                     1
# 51 Haitian Creole             1
# 52 Hungarian                  1
# 53 Ilocano                    1
# 54 Serbian                    1
# 55 Taiwanese                  1

# %%
cohort_demo <- cohort_demo %>%
                    mutate(English = ifelse(language == "English", 1, 0)) %>% 
                    select(-c(language))

cohort_demo %>% count(English)
nrow(cohort_demo)
length(unique(cohort_demo$anon_id))
summary(cohort_demo %>% select(ESI, gender, race, recent_height_cm, recent_weight_kg, age, insurance, English))
# Out:
#   English n
# 1 0        7219
# 2 1       38767
# [1] 45986
# [1] 31584
#       ESI           gender                    race       recent_height_cm
#  Min.   :1.000   Female:21997   Asian           : 6906   Min.   : 12.95
#  1st Qu.:2.000   Male  :23989   Black           : 3279   1st Qu.:160.02
#  Median :3.000                  Native American :  194   Median :167.64
#  Mean   :2.655                  Other           :10554   Mean   :167.97
#  3rd Qu.:3.000                  Pacific Islander:  943   3rd Qu.:175.26
#  Max.   :5.000                  Unknown         :  426   Max.   :210.82
#  NA's   :1861                   White           :23684   NA's   :1420
#  recent_weight_kg      age          insurance         English
#  Min.   :  0.10   Min.   :18.00   Min.   :0.0000   Min.   :0.000
#  1st Qu.: 60.90   1st Qu.:44.00   1st Qu.:0.0000   1st Qu.:1.000
#  Median : 73.10   Median :60.00   Median :0.0000   Median :1.000
#  Mean   : 76.61   Mean   :58.28   Mean   :0.4189   Mean   :0.843
#  3rd Qu.: 88.00   3rd Qu.:73.00   3rd Qu.:1.0000   3rd Qu.:1.000
#  Max.   :320.69   Max.   :90.00   Max.   :1.0000   Max.   :1.000
#  NA's   :311

# %%
head(cohort_demo, n=1)
colnames(cohort_demo)
# Out:
#   anon_id  pat_enc_csn_id_coded label admit_time
# 1 JCe78a06 131062667066         0     2015-01-02 01:01:00
#   inpatient_data_id_coded ESI hosp_admsn_time     ed_time_hr gender race
# 1 13616753                NA  2015-01-01 17:10:00 7.85       Female White
#   recent_height_cm recent_weight_kg insurance recent_date age pub_insurance
# 1 152.4            55.6             1         2020-01-10  83  0
#   English
# 1 1
#  [1] "anon_id"                 "pat_enc_csn_id_coded"
#  [3] "label"                   "admit_time"
#  [5] "inpatient_data_id_coded" "ESI"
#  [7] "hosp_admsn_time"         "ed_time_hr"
#  [9] "gender"                  "race"
# [11] "recent_height_cm"        "recent_weight_kg"
# [13] "insurance"               "recent_date"
# [15] "age"                     "pub_insurance"
# [17] "English"

# %%
# cohort_demo includes cohort, just more variables
write.csv(cohort_demo, file = file.path(datadir, "cohort_demo.csv"), row.names=FALSE)
