# %% [markdown]
# ## Descriptions:
# Process 2 variables from demograhics table
# - Process language --> English: yes/no
# - Process insurance (medicare/caid/cal/mcal/mcare/na) --> yes/no
#
# **Inputs**:
# - `1_2_cohort`: updated 1_1_cohort with inc/exc criteria, which also has demographics information
#
# **Outputs**:
# - `2_1_coh2_demo`

# %% [markdown]
# ### Importing R libraries

# %%
library(bigrquery)  # to query STARR-OMOP (stored in BigQuery) using SQL
library(tidyverse)
library(lubridate)
# library(mice)
# library(VIM) # for missing data plot

# library(data.table)
# library(Matrix)
# library(caret) # import this before glmnet to avoid rlang version problem
# library(glmnet)
# library(bit64)

# library(slam)
# library(mtools) for one hot coder, not available on Nero or use caret or tidyr
options(repr.matrix.max.rows=250, repr.matrix.max.cols=30)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.6
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %% [markdown]
# ### Demographic variables
# - Age (only >=18): done in in/ex criteria
# - insurance = Medical/care/caid and n/a insurance --> medis =1 otherwise 0
# - language --> Engl = 1 for English, otherwise 0
# - leave height and weight to be processed with flowsheet age (>=18 only)

# %%
# datadir = "../../DataTD"
cohortdir = "../../OutputTD/1_cohort"
featuredir = "../../OutputTD/2_features"

cohort <- read.csv(file.path(cohortdir, "1_2_cohort.csv"))
nrow(cohort) #45794
summary(cohort)
# Out:
# [1] 45794
#    anon_id          pat_enc_csn_id_coded     label         admit_time
#  Length:45794       Min.   :1.311e+11    Min.   :0.0000   Length:45794
#  Class :character   1st Qu.:1.312e+11    1st Qu.:0.0000   Class :character
#  Mode  :character   Median :1.312e+11    Median :0.0000   Mode  :character
#                     Mean   :1.312e+11    Mean   :0.1391
#                     3rd Qu.:1.313e+11    3rd Qu.:0.0000
#                     Max.   :1.313e+11    Max.   :1.0000
#
#  inpatient_data_id_coded      ESI        hosp_admsn_time      ed_time_hr
#  Min.   :13616753        Min.   :1.000   Length:45794       Min.   :  0.000
#  1st Qu.:19857182        1st Qu.:2.000   Class :character   1st Qu.:  2.217
#  Median :27890836        Median :3.000   Mode  :character   Median :  3.467
#  Mean   :28153424        Mean   :2.654                      Mean   :  4.811
#  3rd Qu.:34378572        3rd Qu.:3.000                      3rd Qu.:  5.317
#  Max.   :48026130        Max.   :5.000                      Max.   :190.433
#                          NA's   :1861
#     gender              race             language         recent_height_cm
#  Length:45794       Length:45794       Length:45794       Min.   : 12.95
#  Class :character   Class :character   Class :character   1st Qu.:160.02
#  Mode  :character   Mode  :character   Mode  :character   Median :167.64
#                                                           Mean   :167.97
#                                                           3rd Qu.:175.26
#                                                           Max.   :210.82
#                                                           NA's   :1414
#  recent_weight_kg  insurance         recent_date             age
#  Min.   :  0.1    Length:45794       Length:45794       Min.   :18.00
#  1st Qu.: 60.9    Class :character   Class :character   1st Qu.:44.00
#  Median : 73.1    Mode  :character   Mode  :character   Median :60.00
#  Mean   : 76.6                                          Mean   :58.28
#  3rd Qu.: 88.0                                          3rd Qu.:73.00
#  Max.   :320.7                                          Max.   :90.00
#  NA's   :310

# %%
head(cohort, n=1)
# Out:
#   anon_id   pat_enc_csn_id_coded label admit_time
# 1 JC29f8ad2 131274729058         0     2019-08-31 12:52:00
#   inpatient_data_id_coded ESI hosp_admsn_time     ed_time_hr gender race
# 1 40679773                3   2019-08-31 09:59:00 2.883333   Female White
#   language recent_height_cm recent_weight_kg insurance         recent_date age
# 1 English  165.1            83.46            UNITED HEALTHCARE 2020-03-31  52

# %%
cohort <- cohort %>% select(-hosp_admsn_time, -ed_time_hr) %>% # hosp_admsn_time = ymd_hms(hosp_admsn_time)
                mutate(admit_time = ymd_hms(admit_time), recent_date = ymd(recent_date), 
                       gender = factor(gender), race = factor(race), language = factor(language), insurance = factor(insurance)) 
                
nrow(cohort)
summary(cohort)
# Out:
# [1] 45794
#    anon_id          pat_enc_csn_id_coded     label
#  Length:45794       Min.   :1.311e+11    Min.   :0.0000
#  Class :character   1st Qu.:1.312e+11    1st Qu.:0.0000
#  Mode  :character   Median :1.312e+11    Median :0.0000
#                     Mean   :1.312e+11    Mean   :0.1391
#                     3rd Qu.:1.313e+11    3rd Qu.:0.0000
#                     Max.   :1.313e+11    Max.   :1.0000
#
#    admit_time                  inpatient_data_id_coded      ESI
#  Min.   :2015-01-01 08:24:00   Min.   :13616753        Min.   :1.000
#  1st Qu.:2016-05-21 09:49:30   1st Qu.:19857182        1st Qu.:2.000
#  Median :2017-12-31 23:32:00   Median :27890836        Median :3.000
#  Mean   :2017-10-13 02:11:20   Mean   :28153424        Mean   :2.654
#  3rd Qu.:2019-02-19 07:36:45   3rd Qu.:34378572        3rd Qu.:3.000
#  Max.   :2020-03-31 07:00:00   Max.   :48026130        Max.   :5.000
#                                                        NA's   :1861
#     gender                    race             language     recent_height_cm
#  Female:21898   Asian           : 6870   English   :38611   Min.   : 12.95
#  Male  :23896   Black           : 3260   Spanish   : 3672   1st Qu.:160.02
#                 Native American :  195   Mandarin  :  737   Median :167.64
#                 Other           :10511   Vietnamese:  511   Mean   :167.97
#                 Pacific Islander:  930   Cantonese :  266   3rd Qu.:175.26
#                 Unknown         :  424   Russian   :  263   Max.   :210.82
#                 White           :23604   (Other)   : 1734   NA's   :1414
#  recent_weight_kg       insurance      recent_date              age
#  Min.   :  0.1    MEDICARE   :16949   Min.   :2019-01-01   Min.   :18.00
#  1st Qu.: 60.9    BLUE CROSS : 3387   1st Qu.:2019-01-01   1st Qu.:44.00
#  Median : 73.1    HPSM       : 3130   Median :2020-03-11   Median :60.00
#  Mean   : 76.6               : 2724   Mean   :2019-10-29   Mean   :58.28
#  3rd Qu.: 88.0    MEDI-CAL   : 2051   3rd Qu.:2020-03-31   3rd Qu.:73.00
#  Max.   :320.7    BLUE SHIELD: 1891   Max.   :2020-03-31   Max.   :90.00
#  NA's   :310      (Other)    :15662   NA's   :10

# %%
# checking duplicates
nrow(cohort %>% select(anon_id) %>% distinct()) # 31511
nrow(cohort %>% select(anon_id, pat_enc_csn_id_coded) %>% distinct()) # 45794
cohort[duplicated(cohort[, c('anon_id','pat_enc_csn_id_coded')]),]

# cohort %>% filter(anon_id == "JCd49287") # pat_enc_csn_id_coded = 131195706986, 
# cohort <- cohort %>% filter (!(anon_id == "JCd49287" & race == "Unknown"))
# Out:
# [1] 31511
# [1] 45794
#      anon_id pat_enc_csn_id_coded label admit_time inpatient_data_id_coded ESI
#      gender race language recent_height_cm recent_weight_kg insurance
#      recent_date age

# %%
summary(cohort %>% select(ESI, gender, race, recent_height_cm, recent_weight_kg, age))
cohort %>% gather(var, value) %>% distinct() %>% count(var) %>% arrange(n)
cohort %>% summarise_each(funs(n_distinct))
# Out:
#       ESI           gender                    race       recent_height_cm
#  Min.   :1.000   Female:21898   Asian           : 6870   Min.   : 12.95
#  1st Qu.:2.000   Male  :23896   Black           : 3260   1st Qu.:160.02
#  Median :3.000                  Native American :  195   Median :167.64
#  Mean   :2.654                  Other           :10511   Mean   :167.97
#  3rd Qu.:3.000                  Pacific Islander:  930   3rd Qu.:175.26
#  Max.   :5.000                  Unknown         :  424   Max.   :210.82
#  NA's   :1861                   White           :23604   NA's   :1414
#  recent_weight_kg      age
#  Min.   :  0.1    Min.   :18.00
#  1st Qu.: 60.9    1st Qu.:44.00
#  Median : 73.1    Median :60.00
#  Mean   : 76.6    Mean   :58.28
#  3rd Qu.: 88.0    3rd Qu.:73.00
#  Max.   :320.7    Max.   :90.00
#  NA's   :310
# Warning message:
# “attributes are not identical across measure variables;
# they will be dropped”
#    var                     n
# 1  gender                      2
# 2  label                       2
# 3  ESI                         6
# 4  race                        7
# 5  language                   55
# 6  age                        73
# 7  insurance                 134
# 8  recent_date               457
# 9  recent_height_cm          789
# 10 recent_weight_kg         3445
# 11 anon_id                 31511
# 12 admit_time              45260
# 13 inpatient_data_id_coded 45794
# 14 pat_enc_csn_id_coded    45794
# Warning message:
# “`summarise_each_()` was deprecated in dplyr 0.7.0.
# Please use `across()` instead.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”
# Warning message:
# “`funs()` was deprecated in dplyr 0.8.0.
# Please use a list of either functions or lambdas:
#
#   # Simple named list:
#   list(mean = mean, median = median)
#
#   # Auto named with `tibble::lst()`:
#   tibble::lst(mean, median)
#
#   # Using lambdas
#   list(~ mean(., trim = .2), ~ median(., na.rm = TRUE))
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”
#   anon_id pat_enc_csn_id_coded label admit_time inpatient_data_id_coded ESI
# 1 31511   45794                2     45260      45794                   6
#   gender race language recent_height_cm recent_weight_kg insurance recent_date
# 1 2      7    55       789              3445             134       457
#   age
# 1 73

# %% [markdown]
# ### Insurance:

# %%
options(repr.matrix.max.rows=135, repr.matrix.max.cols=20)
cohort %>%                 # filter(!is.na(col)) %>% filter out all rows with NAs in col 
                group_by(insurance) %>% count() %>% arrange(desc(n))
# Out:
#     insurance                                         n
# 1   MEDICARE                                          16949
# 2   BLUE CROSS                                         3387
# 3   HPSM                                               3130
# 4                                                      2724
# 5   MEDI-CAL                                           2051
# 6   BLUE SHIELD                                        1891
# 7   SANTA CLARA FAMILY HP                              1745
# 8   UNITED HEALTHCARE                                  1575
# 9   AETNA                                              1232
# 10  HPSM - MCARE ADV                                   1036
# 11  BLUE CARD (OUT OF STATE)                            979
# 12  CIGNA                                               953
# 13  HEALTHNET                                           702
# 14  MCAL HMO - CENTRAL CALIFORNIA ALLIANCE FOR HEALTH   692
# 15  ALAMEDA ALLIANCE MCAL MGD CARE                      658
# 16  BLUE CROSS MEDI-CAL                                 419
# 17  UNITED HEALTHCARE SR ADV                            419
# 18  UHC MEDICARE AARP COMPLETE                          383
# 19  SCFHP - MCARE ADV                                   363
# 20  BLUE CARD (OUT OF STATE) - BS                       328
# 21  SNF HOSPICE MEDICARE (HOSP ONLY)                    323
# 22  HEALTHNET SENIOR ADVANTAGE                          316
# 23  AETNA CHOICE POS II SHC                             248
# 24  UMR                                                 235
# 25  COMMERCIAL OTHER                                    203
# 26  VETERANS ADMINISTRATION                             197
# 27  MEDICARE SENIOR ADVANTAGE - OTHER                   191
# 28  MEDI-CAL MANAGED CARE                               185
# 29  MCAL HP OF SAN JOAQUIN                              173
# 30  PHP OF CA                                           155
# 31  VALLEY HEALTH PLAN                                  109
# 32  KAISER                                              106
# 33  AARP                                                102
# 34  TRICARE HEALTH NET                                  100
# 35  TRIWEST                                              89
# 36  MANAGED CARE OTHER                                   85
# 37  MCAL HMO-HEALTHNET                                   85
# 38  BLUE CROSS SENIOR                                    84
# 39  MEDICAID                                             80
# 40  MCAL CONTRA COSTA HEALTH PLAN                        74
# 41  UNITEDHEALTHCARE WEST                                71
# 42  HUMANA GOLD CHOICE                                   64
# 43  ALIGNMENT HEALTHPLAN                                 62
# 44  AETNA SENIOR                                         61
# 45  MCAL CENCAL                                          56
# 46  MCAL HMO-SAN FRANCISCO HEALTH PLN                    48
# 47  FIRST HEALTH                                         39
# 48  KAISER SENIOR                                        35
# 49  MULTIPLAN                                            34
# 50  MEDI-CAL CCS                                         31
# 51  VISION SERVICES PLAN                                 31
# 52  WORKERS COMP - OTHER                                 31
# 53  ZZZTRICARE UHC M AND V                               28
# 54  MEDI-CAL ONE TIME DISCOUNT                           25
# 55  PATHWAYS (HOSPITAL ONLY)                             23
# 56  PRIVATE HEALTHCARE SYS (PHCS)                        23
# 57  BSCA PROMISE HEALTH SR ADV                           20
# 58  SUTTER HEALTH PLUS                                   20
# 59  SUTTER HEALTH SYSTEM                                 20
# 60  CAREMORE ANTHEM SR ADV                               18
# 61  TRICARE FOR LIFE                                     15
# 62  GOV-OTHER                                            13
# 63  HUMANA CHOICE CARE                                   12
# 64  MEDI-CAL MGD CARE COUNTY                             12
# 65  INTERNATIONAL                                        11
# 66  U.S. BEHAVIORAL HEALTH                               11
# 67  MCAL KAISER OAKLAND                                  10
# 68  MUTUAL OF OMAHA                                      10
# 69  BENEFIT RISK MGMT                                     9
# 70  UNITED HEALTH CARE                                    9
# 71  BRAND NEW DAY SR ADV                                  8
# 72  COM-OTHER                                             8
# 73  HOMETOWN HEALTH PLAN                                  8
# 74  OPTUM HEALTH/URN                                      8
# 75  HOMETOWN HP SENIOR                                    7
# 76  MCAL HMO-MOLINA                                       7
# 77  AETNA SHC ALLIANCE                                    6
# 78  ASPIRE HEALTH PLAN SR ADV                             6
# 79  CA DEPT OF CORRECTIONS                                6
# 80  CHAMPVA                                               6
# 81  MANAGED HEALTH NETWORK                                6
# 82  VITALITY HEALTH PLAN SR ADV                           6
# 83  BLUE CARD SR ADV (OUT OF STATE) - BS                  5
# 84  WORKERS COMP - STATE COMP                             5
# 85  BLUE CARD SR ADV (OUT OF STATE) - BX                  4
# 86  EMPLOYER BASED PAYOR                                  4
# 87  INTERPLAN                                             4
# 88  MCAL KAISER SANTA CLARA                               4
# 89  UHC MEDICARE AARP COMPLETE PPO                        4
# 90  WORKERS COMP - TRAVELERS INS                          4
# 91  BLUE CARD-BX/BS OUT-OF-STATE                          3
# 92  BLUE DIST CTR FOR TRANSPLANT                          3
# 93  COVENTRY HEALTH CARE                                  3
# 94  HEALTH NET                                            3
# 95  MCAL CALOPTIMA                                        3
# 96  MCAL KAISER HAYWARD                                   3
# 97  MEDICAID HMO                                          3
# 98  PENDING INSURANCE                                     3
# 99  SCAN HEALTH PLAN                                      3
# 100 WORKERS COMP - ZURICH (SU EMP)                        3
# 101 AETNA SUTTER HEALTH                                   2
# 102 GOLDEN STATE MHP                                      2
# 103 MEDICAID OUT OF STATE                                 2
# 104 NETWORKS BY DESIGN                                    2
# 105 WORKERS COMP - FARMERS INS                            2
# 106 WORKERS COMP - MATRIX                                 2
# 107 CCS HEALTH PLAN SAN MATEO                             1
# 108 COUNTY CORRECTIONS                                    1
# 109 DONOR NETWORK WEST                                    1
# 110 GEHA                                                  1
# 111 HEALTHY FAMILIES                                      1
# 112 HEALTHY KIDS                                          1
# 113 HPSM - CCS                                            1
# 114 JOHN MUIR                                             1
# 115 MC AETNA COMM AFMG                                    1
# 116 NORTHERN NEVADA TRUST FUND                            1
# 117 OPTUM                                                 1
# 118 PHYSICIANS FOUNDATION                                 1
# 119 SAMARITAN CHOICE PLAN                                 1
# 120 SHCA COMM AETNA                                       1
# 121 THE SEQUOIAS                                          1
# 122 USA MANAGED CARE SENIOR                               1
# 123 VICTIM VIOLENT CRIME                                  1
# 124 WORKERS COMP - AIG/CHARTIS                            1
# 125 WORKERS COMP - ATHENS                                 1
# 126 WORKERS COMP - CITY/CNTY S.F.                         1
# 127 WORKERS COMP - ESIS                                   1
# 128 WORKERS COMP - GALLAGHER BSET                         1
# 129 WORKERS COMP - INNOV CARE SYS                         1
# 130 WORKERS COMP - LIBERTY MUTUAL                         1
# 131 WORKERS COMP - REPUBLIC INDEMN                        1
# 132 WORKERS COMP - US DEPT OF ENERGY-OWCP                 1
# 133 ZZZALAMEDA ALLIANCE MEDICARE ADV-                     1
# 134 ZZZWORKERS COMP - CORVEL                              1

# %%
# check for medicare/ medical/ no insurance
# cohort %>% filter(str_detect(insurance, "MEDI") | insurance == "") %>% 
#                 group_by(insurance) %>% count() %>% arrange(-n)

# mcal = medical, mcare = medicare
medis <- c("MEDI", "MCAL", "MCARE")
cohort %>% filter(str_detect(insurance, paste(medis, collapse = "|")) | insurance == "") %>% 
                group_by(insurance) %>% count() %>% arrange(-n)
# Out:
#    insurance                                         n
# 1  MEDICARE                                          16949
# 2                                                     2724
# 3  MEDI-CAL                                           2051
# 4  HPSM - MCARE ADV                                   1036
# 5  MCAL HMO - CENTRAL CALIFORNIA ALLIANCE FOR HEALTH   692
# 6  ALAMEDA ALLIANCE MCAL MGD CARE                      658
# 7  BLUE CROSS MEDI-CAL                                 419
# 8  UHC MEDICARE AARP COMPLETE                          383
# 9  SCFHP - MCARE ADV                                   363
# 10 SNF HOSPICE MEDICARE (HOSP ONLY)                    323
# 11 MEDICARE SENIOR ADVANTAGE - OTHER                   191
# 12 MEDI-CAL MANAGED CARE                               185
# 13 MCAL HP OF SAN JOAQUIN                              173
# 14 MCAL HMO-HEALTHNET                                   85
# 15 MEDICAID                                             80
# 16 MCAL CONTRA COSTA HEALTH PLAN                        74
# 17 MCAL CENCAL                                          56
# 18 MCAL HMO-SAN FRANCISCO HEALTH PLN                    48
# 19 MEDI-CAL CCS                                         31
# 20 MEDI-CAL ONE TIME DISCOUNT                           25
# 21 MEDI-CAL MGD CARE COUNTY                             12
# 22 MCAL KAISER OAKLAND                                  10
# 23 MCAL HMO-MOLINA                                       7
# 24 MCAL KAISER SANTA CLARA                               4
# 25 UHC MEDICARE AARP COMPLETE PPO                        4
# 26 MCAL CALOPTIMA                                        3
# 27 MCAL KAISER HAYWARD                                   3
# 28 MEDICAID HMO                                          3
# 29 MEDICAID OUT OF STATE                                 2
# 30 ZZZALAMEDA ALLIANCE MEDICARE ADV-                     1

# %%
# turn insurance into medis which has "MEDI" under insurance
# insurance = 0 if patient has medis or no insurance, 1 for other insurance
medis <- c("MEDI", "MCAL", "MCARE")

nrow(cohort %>% filter(insurance == "")) # 2737
nrow(cohort %>% filter(str_detect(insurance, "MEDI"))) # 20766
nrow(cohort %>% filter(str_detect(insurance, paste(medis, collapse = "|")))) # 23987

cohort_demo <- cohort %>%
                    mutate(insurance = ifelse(str_detect(insurance, paste(medis, collapse = "|")) | insurance == "", 0, 1)) %>%
                    group_by(anon_id, pat_enc_csn_id_coded) %>%
                    mutate(insurance = sum(insurance)) %>% ungroup() %>% # just to make sure if anyone else has more than 1
                    mutate(insurance = ifelse(insurance>0, 1, insurance)) 

cohort_demo %>% count(insurance)
# Out:
# [1] 2724
# [1] 20659
# [1] 23871
#   insurance n
# 1 0         26595
# 2 1         19199

# %% [markdown]
# ### Language:

# %%
cohort_demo %>% group_by(language) %>% count() %>% arrange(desc(n))
# Out:
#    language               n
# 1  English                38611
# 2  Spanish                 3672
# 3  Mandarin                 737
# 4  Vietnamese               511
# 5  Cantonese                266
# 6  Russian                  263
# 7  Farsi                    261
# 8  Tongan                   212
# 9  Tagalog                  179
# 10 Korean                   152
# 11 Other                    136
# 12 Hindi                    113
# 13 Punjabi (Panjabi)         99
# 14 Dari                      82
# 15 Arabic                    66
# 16 Japanese                  50
# 17 Unknown                   40
# 18 Portuguese                35
# 19 Samoan                    32
# 20 Burmese                   25
# 21                           21
# 22 Deaf/Non-Sign Language    21
# 23 French                    20
# 24 Urdu                      19
# 25 Italian                   18
# 26 American Sign Language    17
# 27 Cambodian, Mon-Khmer      13
# 28 Polish                    12
# 29 Greek                     11
# 30 Gujarati                  10
# 31 Persian                   10
# 32 Telugu                    10
# 33 Hebrew                     8
# 34 Hmong                      8
# 35 Albanian                   7
# 36 Romanian                   7
# 37 Indonesian                 6
# 38 Laotian                    6
# 39 Armenian                   5
# 40 Traditional Chinese        4
# 41 Croatian                   2
# 42 Hindu                      2
# 43 Mien (lu Mien)             2
# 44 Thai                       2
# 45 Amharic                    1
# 46 Bosnian                    1
# 47 canadian french            1
# 48 Creole, French             1
# 49 Fijian                     1
# 50 German                     1
# 51 Haitian Creole             1
# 52 Hungarian                  1
# 53 Ilocano                    1
# 54 Serbian                    1
# 55 Taiwanese                  1

# %%
cohort_demo <- cohort_demo %>%
                    mutate(English = ifelse(language == "English", 1, 0)) %>% 
                    select(-c(language))

cohort_demo %>% count(English)
nrow(cohort_demo)
length(unique(cohort_demo$anon_id))
summary(cohort_demo %>% select(ESI, gender, race, recent_height_cm, recent_weight_kg, age, insurance, English))
# Out:
#   English n
# 1 0        7183
# 2 1       38611
# [1] 45794
# [1] 31511
#       ESI           gender                    race       recent_height_cm
#  Min.   :1.000   Female:21898   Asian           : 6870   Min.   : 12.95
#  1st Qu.:2.000   Male  :23896   Black           : 3260   1st Qu.:160.02
#  Median :3.000                  Native American :  195   Median :167.64
#  Mean   :2.654                  Other           :10511   Mean   :167.97
#  3rd Qu.:3.000                  Pacific Islander:  930   3rd Qu.:175.26
#  Max.   :5.000                  Unknown         :  424   Max.   :210.82
#  NA's   :1861                   White           :23604   NA's   :1414
#  recent_weight_kg      age          insurance         English
#  Min.   :  0.1    Min.   :18.00   Min.   :0.0000   Min.   :0.0000
#  1st Qu.: 60.9    1st Qu.:44.00   1st Qu.:0.0000   1st Qu.:1.0000
#  Median : 73.1    Median :60.00   Median :0.0000   Median :1.0000
#  Mean   : 76.6    Mean   :58.28   Mean   :0.4192   Mean   :0.8431
#  3rd Qu.: 88.0    3rd Qu.:73.00   3rd Qu.:1.0000   3rd Qu.:1.0000
#  Max.   :320.7    Max.   :90.00   Max.   :1.0000   Max.   :1.0000
#  NA's   :310

# %%
head(cohort_demo, n=1)
colnames(cohort_demo)
# Out:
#   anon_id   pat_enc_csn_id_coded label admit_time
# 1 JC29f8ad2 131274729058         0     2019-08-31 12:52:00
#   inpatient_data_id_coded ESI gender race  recent_height_cm recent_weight_kg
# 1 40679773                3   Female White 165.1            83.46
#   insurance recent_date age English
# 1 1         2020-03-31  52  1
#  [1] "anon_id"                 "pat_enc_csn_id_coded"
#  [3] "label"                   "admit_time"
#  [5] "inpatient_data_id_coded" "ESI"
#  [7] "gender"                  "race"
#  [9] "recent_height_cm"        "recent_weight_kg"
# [11] "insurance"               "recent_date"
# [13] "age"                     "English"

# %%
# save file cohort_demo
write.csv(cohort_demo, file = file.path(featuredir, "2_1_coh2_demo.csv"), row.names=FALSE)
