# %% [markdown]
# # Length of stay in ED
#
# Look at the length of stay in emergency department for all cases.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy import stats

# %%
# adjust this to hide ID columns for posting to github
forrepo=False

hidecols = []
if forrepo:
    hidecols=['anon_id', 'pat_enc_csn_id_coded', 'inpatient_data_id_coded'] # these are hidden columns

# %%
# view data frame

# adjust this to hide ID columns for posting to github
forrepo=False

def view_df(df):
    hidecols = []
    if forrepo:
        hidecols=['anon_id', 'pat_enc_csn_id_coded', 'inpatient_data_id_coded'] # these are hidden columns
        
    return(df.drop(hidecols, axis=1, errors='ignore').head())

# %% [markdown]
# Pulled adt table from sch_core_2021 for the 6_7 cohort using the following SQL:
#
# ```select *
#     from `som-nero-phi-jonc101.shc_core_2021.adt` as adt
#     where adt.pat_enc_csn_id_coded
#     in (
#         select pat_enc_csn_id_coded from
#             `som-nero-phi-jonc101.triageTD.6_7_cohort4`
#     )```

# %%
# read in data files
datadir = "../../DataTD/shc2021"
outdir = "../../OutputTD/shc2021"

adt_file = datadir + "/cohort3_adt_2021.csv"
# new_adt_file = datadir + "/cohort_6_7_adt.csv"
# results_file = resultsdir + "1_4_cohort_test_results.csv"
cohort_file = "../../OutputTD/shc2021/7_cohort4_3hr_labels_noOR.csv"


adt = pd.read_csv(adt_file)
# adt_2021 = pd.read_csv(new_adt_file)
# results = pd.read_csv(results_file)
cohort = pd.read_csv(cohort_file)

# %%
# just checking the cohorts
csns = cohort.pat_enc_csn_id_coded.unique()
adt_csns = adt.pat_enc_csn_id_coded.unique()

print("cohort csns: {}".format(len(csns)))
print("adt csns: {}".format(len(adt_csns)))

adt = adt[adt.pat_enc_csn_id_coded.isin(cohort.pat_enc_csn_id_coded)]
print(adt.pat_enc_csn_id_coded.nunique())
# Out:
# cohort csns: 52532
# adt csns: 61176
# 52532

# %% [raw]
# # join the two adt tables together
# full_adt = pd.concat([adt, adt_2021])
# print(full_adt.pat_enc_csn_id_coded.nunique())
#
# # keep only csns in our cohort
# filtered_adt = full_adt[full_adt.pat_enc_csn_id_coded.isin(cohort.pat_enc_csn_id_coded)]
# filtered_adt.head()
#
# adt = filtered_adt # rename
# adt.pat_enc_csn_id_coded.nunique()

# %% [raw]
# # save this full adt table for later
# savefile = "../../DataTD/cohort_6_7_all_adt.csv"
# adt.to_csv(savefile, index=False)

# %% [raw]
# # csns in our test cohort
# results.pat_enc_csn_id_coded.nunique()

# %% [markdown]
# # Format data
#
# Convert datetime columns to the correct format.

# %%
adt.columns
# Out:
# Index(['anon_id', 'pat_enc_csn_id_coded', 'effective_time_jittered_utc',
#        'seq_num_in_enc', 'pat_class', 'base_pat_class_c', 'pat_lvl_of_care_c',
#        'pat_lv_of_care', 'event_type', 'pat_service', 'department_id'],
#       dtype='object')

# %%
# add year of admit
adt['effective_year'] = pd.DatetimeIndex(adt['effective_time_jittered_utc']).year
adt.drop(hidecols, axis=1, errors='ignore').head()
# Out:
#      anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 0  JC2210295          131259986092   2018-12-13 07:59:00+00:00
# 1  JC1259166          131251987857   2018-07-05 06:59:00+00:00
# 2  JC1259166          131251987857   2018-07-03 23:20:00+00:00
# 3   JC652959          131293920824   2020-08-17 05:59:00+00:00
# 4   JC652959          131293920824   2020-08-16 22:43:00+00:00
#
#    seq_num_in_enc  pat_class  base_pat_class_c  pat_lvl_of_care_c  \
# 0              12  Inpatient               NaN                5.0
# 1              21  Inpatient               NaN                9.0
# 2              19  Inpatient               NaN                9.0
# 3              24  Inpatient               NaN                8.0
# 4              19  Inpatient               NaN                9.0
#
#                                       pat_lv_of_care      event_type  \
# 0       Acute Care (Assessment or intervention q4-8)          Census
# 1  IICU/Intermediate Care (Assessment or interven...          Census
# 2  IICU/Intermediate Care (Assessment or interven...  Patient Update
# 3                                      Critical Care     Transfer In
# 4  IICU/Intermediate Care (Assessment or interven...  Patient Update
#
#               pat_service  department_id  effective_year
# 0   Cystic Fibrosis Adult      2000238.0            2018
# 1  Pulmonary Hypertension      2000237.0            2018
# 2  Pulmonary Hypertension      2000237.0            2018
# 3      Neurocritical Care      6001003.0            2020
# 4      Neurocritical Care    110100014.0            2020

# %%
# change the effective time to datetime since read in from csv
adt.effective_time_jittered_utc = pd.to_datetime(adt.effective_time_jittered_utc)
print(adt.pat_enc_csn_id_coded.nunique())
# Out:
# 52532

# %%
# add the admit time column from the prediction results csv to the adt csv
admit_time = cohort[['pat_enc_csn_id_coded', 'admit_time']]

adt_admit = adt.merge(admit_time, how='left')
print(adt.pat_enc_csn_id_coded.nunique())
# adt.head()

adt_admit.admit_time = pd.to_datetime(adt_admit.admit_time, utc=True)

adt_admit.columns
# Out:
# 52532
# Index(['anon_id', 'pat_enc_csn_id_coded', 'effective_time_jittered_utc',
#        'seq_num_in_enc', 'pat_class', 'base_pat_class_c', 'pat_lvl_of_care_c',
#        'pat_lv_of_care', 'event_type', 'pat_service', 'department_id',
#        'effective_year', 'admit_time'],
#       dtype='object')

# %%
# do we still have all of the CSNs? - YES
adt_admit.pat_enc_csn_id_coded.nunique()
# Out:
# 52532

# %%
adt_admit.drop(hidecols, axis=1, errors='ignore').head()
# Out:
#      anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 0  JC2210295          131259986092   2018-12-13 07:59:00+00:00
# 1  JC1259166          131251987857   2018-07-05 06:59:00+00:00
# 2  JC1259166          131251987857   2018-07-03 23:20:00+00:00
# 3   JC652959          131293920824   2020-08-17 05:59:00+00:00
# 4   JC652959          131293920824   2020-08-16 22:43:00+00:00
#
#    seq_num_in_enc  pat_class  base_pat_class_c  pat_lvl_of_care_c  \
# 0              12  Inpatient               NaN                5.0
# 1              21  Inpatient               NaN                9.0
# 2              19  Inpatient               NaN                9.0
# 3              24  Inpatient               NaN                8.0
# 4              19  Inpatient               NaN                9.0
#
#                                       pat_lv_of_care      event_type  \
# 0       Acute Care (Assessment or intervention q4-8)          Census
# 1  IICU/Intermediate Care (Assessment or interven...          Census
# 2  IICU/Intermediate Care (Assessment or interven...  Patient Update
# 3                                      Critical Care     Transfer In
# 4  IICU/Intermediate Care (Assessment or interven...  Patient Update
#
#               pat_service  department_id  effective_year  \
# 0   Cystic Fibrosis Adult      2000238.0            2018
# 1  Pulmonary Hypertension      2000237.0            2018
# 2  Pulmonary Hypertension      2000237.0            2018
# 3      Neurocritical Care      6001003.0            2020
# 4      Neurocritical Care    110100014.0            2020
#
#                  admit_time
# 0 2018-12-11 04:40:00+00:00
# 1 2018-06-27 20:37:00+00:00
# 2 2018-06-27 20:37:00+00:00
# 3 2020-08-11 16:05:00+00:00
# 4 2020-08-11 16:05:00+00:00

# %%
# compute the time before admit for each of these events
adt_admit['time_before_admit'] = adt_admit.apply(lambda x: x.admit_time - x.effective_time_jittered_utc, axis=1)
print(adt_admit.pat_enc_csn_id_coded.nunique())
adt_admit.drop(hidecols, axis=1, errors='ignore').head()
# Out:
# 52532
#      anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 0  JC2210295          131259986092   2018-12-13 07:59:00+00:00
# 1  JC1259166          131251987857   2018-07-05 06:59:00+00:00
# 2  JC1259166          131251987857   2018-07-03 23:20:00+00:00
# 3   JC652959          131293920824   2020-08-17 05:59:00+00:00
# 4   JC652959          131293920824   2020-08-16 22:43:00+00:00
#
#    seq_num_in_enc  pat_class  base_pat_class_c  pat_lvl_of_care_c  \
# 0              12  Inpatient               NaN                5.0
# 1              21  Inpatient               NaN                9.0
# 2              19  Inpatient               NaN                9.0
# 3              24  Inpatient               NaN                8.0
# 4              19  Inpatient               NaN                9.0
#
#                                       pat_lv_of_care      event_type  \
# 0       Acute Care (Assessment or intervention q4-8)          Census
# 1  IICU/Intermediate Care (Assessment or interven...          Census
# 2  IICU/Intermediate Care (Assessment or interven...  Patient Update
# 3                                      Critical Care     Transfer In
# 4  IICU/Intermediate Care (Assessment or interven...  Patient Update
#
#               pat_service  department_id  effective_year  \
# 0   Cystic Fibrosis Adult      2000238.0            2018
# 1  Pulmonary Hypertension      2000237.0            2018
# 2  Pulmonary Hypertension      2000237.0            2018
# 3      Neurocritical Care      6001003.0            2020
# 4      Neurocritical Care    110100014.0            2020
#
#                  admit_time time_before_admit
# 0 2018-12-11 04:40:00+00:00 -3 days +20:41:00
# 1 2018-06-27 20:37:00+00:00 -8 days +13:38:00
# 2 2018-06-27 20:37:00+00:00 -7 days +21:17:00
# 3 2020-08-11 16:05:00+00:00 -6 days +10:06:00
# 4 2020-08-11 16:05:00+00:00 -6 days +17:22:00

# %% [markdown]
# We want to find the length of stay in the ED, so we'll add some columns to help figure out which ADT events mark the admission to Emergency services and transfer to Inpatient.
#
# We're looking for:
#
# - the first Inpatient event that follow Emergency Services (should be admit time)
# - the first Emergency Services event

# %%
# mark the events with some labels that make things easier later

# sort by csn and time
adt_admit.sort_values(['pat_enc_csn_id_coded', 'seq_num_in_enc'], inplace=True)

# **assumes dataframe is sorted by time

# the first inpatient event following Emergency Services must meet these three criteria:
    # mark whether previous entry had pat class Emergency Services
adt_admit['prev_emerg'] = adt_admit.pat_class.shift() == 'Emergency Services'
    # mark whether current event has pat class Inpatient
adt_admit['curr_inpatient'] = adt_admit.pat_class == 'Inpatient'
    # mark whether current event is continued csn as previous
adt_admit['continued'] = adt_admit.pat_enc_csn_id_coded.eq(
    adt_admit.pat_enc_csn_id_coded.shift())

# find our cases by taking the AND of these columns
cols = ['prev_emerg', 'curr_inpatient', 'continued']
adt_admit['first_ip'] = adt_admit[cols].all(axis=1)

print(adt_admit.pat_enc_csn_id_coded.nunique())
adt_admit.drop(hidecols, axis=1, errors='ignore').head()
# Out:
# 52532
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 283731  JC1170548          131062572931   2015-01-01 18:40:00+00:00
# 283906  JC1170548          131062572931   2015-01-02 03:09:00+00:00
# 283445  JC1170548          131062572931   2015-01-02 03:09:00+00:00
# 283031  JC1170548          131062572931   2015-01-02 03:48:00+00:00
# 887228  JC1170548          131062572931   2015-01-02 03:48:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 283731               1  Emergency Services               3.0
# 283906               2  Emergency Services               NaN
# 283445               3  Emergency Services               NaN
# 283031               4  Emergency Services               NaN
# 887228               5           Inpatient               1.0
#
#         pat_lvl_of_care_c                            pat_lv_of_care  \
# 283731                NaN                                       NaN
# 283906                NaN                                       NaN
# 283445                NaN                                       NaN
# 283031                NaN                                       NaN
# 887228                6.0  Intermediate Care - With Cardiac Monitor
#
#           event_type                    pat_service  department_id  \
# 283731     Admission                      Emergency      2001002.0
# 283906  Transfer Out                      Emergency      2001002.0
# 283445   Transfer In                      Emergency      2001002.0
# 283031  Transfer Out                      Emergency      2001002.0
# 887228   Transfer In  General Medicine (University)      2000237.0
#
#         effective_year                admit_time time_before_admit  \
# 283731            2015 2015-01-02 03:48:00+00:00   0 days 09:08:00
# 283906            2015 2015-01-02 03:48:00+00:00   0 days 00:39:00
# 283445            2015 2015-01-02 03:48:00+00:00   0 days 00:39:00
# 283031            2015 2015-01-02 03:48:00+00:00   0 days 00:00:00
# 887228            2015 2015-01-02 03:48:00+00:00   0 days 00:00:00
#
#         prev_emerg  curr_inpatient  continued  first_ip
# 283731       False           False      False     False
# 283906        True           False       True     False
# 283445        True           False       True     False
# 283031        True           False       True     False
# 887228        True            True       True      True

# %% [markdown]
# Find the first emergency services pat_class for each csn.

# %%
# start by taking events that have a different pat class from the next event (below it)
change_pat = adt_admit[~adt_admit.pat_class.eq(adt_admit.pat_class.shift())]
print(change_pat.pat_enc_csn_id_coded.nunique())
change_pat.drop(hidecols, axis=1, errors='ignore').head()
# Out:
# 52532
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 283731  JC1170548          131062572931   2015-01-01 18:40:00+00:00
# 887228  JC1170548          131062572931   2015-01-02 03:48:00+00:00
# 354402   JC913990          131062745090   2015-01-02 01:56:00+00:00
# 765487   JC913990          131062745090   2015-01-02 05:53:00+00:00
# 307756   JC529112          131062927111   2015-01-04 18:13:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 283731               1  Emergency Services               3.0
# 887228               5           Inpatient               1.0
# 354402               1  Emergency Services               3.0
# 765487               9           Inpatient               1.0
# 307756               1  Emergency Services               3.0
#
#         pat_lvl_of_care_c                                pat_lv_of_care  \
# 283731                NaN                                           NaN
# 887228                6.0      Intermediate Care - With Cardiac Monitor
# 354402                NaN                                           NaN
# 765487                5.0  Acute Care (Assessment or intervention q4-8)
# 307756                NaN                                           NaN
#
#          event_type                    pat_service  department_id  \
# 283731    Admission                      Emergency      2001002.0
# 887228  Transfer In  General Medicine (University)      2000237.0
# 354402    Admission                      Emergency      2001002.0
# 765487  Transfer In            Orthopaedic Surgery      2000250.0
# 307756    Admission                      Emergency      2001002.0
#
#         effective_year                admit_time time_before_admit  \
# 283731            2015 2015-01-02 03:48:00+00:00   0 days 09:08:00
# 887228            2015 2015-01-02 03:48:00+00:00   0 days 00:00:00
# 354402            2015 2015-01-02 05:53:00+00:00   0 days 03:57:00
# 765487            2015 2015-01-02 05:53:00+00:00   0 days 00:00:00
# 307756            2015 2015-01-05 03:20:00+00:00   0 days 09:07:00
#
#         prev_emerg  curr_inpatient  continued  first_ip
# 283731       False           False      False     False
# 887228        True            True       True      True
# 354402       False           False      False     False
# 765487        True            True       True      True
# 307756       False           False      False     False

# %%
# keep the event with pat_class == Emergency Services, that occurs before the first inpatient event
# check to make sure that we're looking at the same CSN between both events
# don't take any where admit ocurred before ER event - happens when people move around a lot (ER -> Inpatient -> ER -> Inpatient)
keep_visits = change_pat[(change_pat.pat_class == 'Emergency Services') & 
                         (change_pat.shift(-1).first_ip) &
                         (change_pat.shift(-1).pat_enc_csn_id_coded == change_pat.pat_enc_csn_id_coded) & 
                         (change_pat.time_before_admit >= timedelta(days=0))] # remove this for now # ??? same results with this set

print(keep_visits.pat_enc_csn_id_coded.nunique())
keep_visits.drop(hidecols, axis=1, errors='ignore').head()
# Out:
# 52530
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 283731  JC1170548          131062572931   2015-01-01 18:40:00+00:00
# 354402   JC913990          131062745090   2015-01-02 01:56:00+00:00
# 307756   JC529112          131062927111   2015-01-04 18:13:00+00:00
# 325130  JC1702404          131063006922   2015-01-06 09:04:00+00:00
# 284725   JC523028          131063022232   2015-01-03 14:51:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 283731               1  Emergency Services               3.0
# 354402               1  Emergency Services               3.0
# 307756               1  Emergency Services               3.0
# 325130               1  Emergency Services               3.0
# 284725               1  Emergency Services               3.0
#
#         pat_lvl_of_care_c pat_lv_of_care event_type pat_service  \
# 283731                NaN            NaN  Admission   Emergency
# 354402                NaN            NaN  Admission   Emergency
# 307756                NaN            NaN  Admission   Emergency
# 325130                NaN            NaN  Admission   Emergency
# 284725                NaN            NaN  Admission   Emergency
#
#         department_id  effective_year                admit_time  \
# 283731      2001002.0            2015 2015-01-02 03:48:00+00:00
# 354402      2001002.0            2015 2015-01-02 05:53:00+00:00
# 307756      2001002.0            2015 2015-01-05 03:20:00+00:00
# 325130      2001002.0            2015 2015-01-06 14:47:00+00:00
# 284725      2001002.0            2015 2015-01-03 21:24:00+00:00
#
#        time_before_admit  prev_emerg  curr_inpatient  continued  first_ip
# 283731   0 days 09:08:00       False           False      False     False
# 354402   0 days 03:57:00       False           False      False     False
# 307756   0 days 09:07:00       False           False      False     False
# 325130   0 days 05:43:00       False           False      False     False
# 284725   0 days 06:33:00       False           False      False     False

# %%
# look at the number of csn's that were dropped becuase admit time was before first ER event
print(change_pat.pat_enc_csn_id_coded.nunique())

print(keep_visits.pat_enc_csn_id_coded.nunique())

# we lose csns where admit occurs before the first ER - lost 2
# Out:
# 61176
# 52530

# %%
# check to see if all of the remaining rows are with seq=1
print(keep_visits.seq_num_in_enc.describe())
keep_visits[keep_visits['seq_num_in_enc'] > 1]
# Out:
# count    52530.000000
# mean         1.000038
# std          0.008726
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# Name: seq_num_in_enc, dtype: float64
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 264400  JC1926085          131246488352   2018-02-02 09:26:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 264400               3  Emergency Services               3.0
#
#         pat_lvl_of_care_c                                pat_lv_of_care  \
# 264400                5.0  Acute Care (Assessment or intervention q4-8)
#
#             event_type pat_service  department_id  effective_year  \
# 264400  Patient Update   Emergency      2001002.0            2018
#
#                       admit_time time_before_admit  prev_emerg  \
# 264400 2018-02-03 00:40:00+00:00   0 days 15:14:00       False
#
#         curr_inpatient  continued  first_ip
# 264400           False       True     False

# %%
# change_pat.dtypes

# %%
# no one has admit_time before ED, quickest admit
keep_visits.sort_values('time_before_admit').head(1)
# Out:
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 377391  JC2812249          131277235724   2019-10-22 00:02:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 377391               1  Emergency Services               3.0
#
#         pat_lvl_of_care_c pat_lv_of_care event_type pat_service  \
# 377391                NaN            NaN  Admission   Emergency
#
#         department_id  effective_year                admit_time  \
# 377391      2001002.0            2019 2019-10-22 00:03:00+00:00
#
#        time_before_admit  prev_emerg  curr_inpatient  continued  first_ip
# 377391   0 days 00:01:00       False           False      False     False

# %%
# no one has admit_time before ED, latest admit
keep_visits.sort_values('time_before_admit').tail(1)
# Out:
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 290406  JC1840822          131090609481   2015-07-02 20:22:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 290406               1  Emergency Services               3.0
#
#         pat_lvl_of_care_c pat_lv_of_care event_type pat_service  \
# 290406                NaN            NaN  Admission   Emergency
#
#         department_id  effective_year                admit_time  \
# 290406      2001002.0            2015 2015-07-10 18:48:00+00:00
#
#        time_before_admit  prev_emerg  curr_inpatient  continued  first_ip
# 290406   7 days 22:26:00       False           False      False     False

# %%
# check the first patient who was admitted 1 min after presenting in ED
adt_admit[adt_admit['pat_enc_csn_id_coded'] == 131277235724].head(2)
# Out:
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 377391  JC2812249          131277235724   2019-10-22 00:02:00+00:00
# 377293  JC2812249          131277235724   2019-10-22 00:03:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 377391               1  Emergency Services               3.0
# 377293               2           Inpatient               1.0
#
#         pat_lvl_of_care_c                                pat_lv_of_care  \
# 377391                NaN                                           NaN
# 377293                5.0  Acute Care (Assessment or intervention q4-8)
#
#             event_type pat_service  department_id  effective_year  \
# 377391       Admission   Emergency      2001002.0            2019
# 377293  Patient Update   Emergency      2001002.0            2019
#
#                       admit_time time_before_admit  prev_emerg  \
# 377391 2019-10-22 00:03:00+00:00   0 days 00:01:00       False
# 377293 2019-10-22 00:03:00+00:00   0 days 00:00:00        True
#
#         curr_inpatient  continued  first_ip
# 377391           False      False     False
# 377293            True       True      True

# %%
# the only case with seq > 1 and it happned that patient was under obs before moved to emergency, 
# also pat_service is indication rather than pat_class
adt_admit[adt_admit['pat_enc_csn_id_coded'] == 131246488352].head(10)
# Out:
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 264480  JC1926085          131246488352   2018-02-02 00:01:00+00:00
# 264475  JC1926085          131246488352   2018-02-02 07:59:00+00:00
# 264400  JC1926085          131246488352   2018-02-02 09:26:00+00:00
# 264272  JC1926085          131246488352   2018-02-02 10:28:00+00:00
# 264948  JC1926085          131246488352   2018-02-02 10:28:00+00:00
# 264309  JC1926085          131246488352   2018-02-02 10:51:00+00:00
# 264115  JC1926085          131246488352   2018-02-03 00:36:00+00:00
# 264276  JC1926085          131246488352   2018-02-03 00:36:00+00:00
# 264830  JC1926085          131246488352   2018-02-03 00:40:00+00:00
# 869186  JC1926085          131246488352   2018-02-03 00:40:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 264480               1         Observation               2.0
# 264475               2         Observation               NaN
# 264400               3  Emergency Services               3.0
# 264272               4  Emergency Services               NaN
# 264948               5  Emergency Services               NaN
# 264309               6  Emergency Services               NaN
# 264115               7  Emergency Services               NaN
# 264276               8  Emergency Services               NaN
# 264830               9  Emergency Services               NaN
# 869186              10           Inpatient               1.0
#
#         pat_lvl_of_care_c                                pat_lv_of_care  \
# 264480                NaN                                           NaN
# 264475                NaN                                           NaN
# 264400                5.0  Acute Care (Assessment or intervention q4-8)
# 264272                5.0  Acute Care (Assessment or intervention q4-8)
# 264948                5.0  Acute Care (Assessment or intervention q4-8)
# 264309                5.0  Acute Care (Assessment or intervention q4-8)
# 264115                5.0  Acute Care (Assessment or intervention q4-8)
# 264276                5.0  Acute Care (Assessment or intervention q4-8)
# 264830                5.0  Acute Care (Assessment or intervention q4-8)
# 869186                5.0  Acute Care (Assessment or intervention q4-8)
#
#             event_type                    pat_service  department_id  \
# 264480       Admission                      Emergency      2001002.0
# 264475          Census                      Emergency      2001002.0
# 264400  Patient Update                      Emergency      2001002.0
# 264272    Transfer Out                      Emergency      2001002.0
# 264948     Transfer In                      Emergency      2001002.0
# 264309  Patient Update                      Emergency      2001002.0
# 264115    Transfer Out                      Emergency      2001002.0
# 264276     Transfer In                      Emergency      2001002.0
# 264830    Transfer Out                      Emergency      2001002.0
# 869186     Transfer In  General Medicine (University)      2000237.0
#
#         effective_year                admit_time time_before_admit  \
# 264480            2018 2018-02-03 00:40:00+00:00   1 days 00:39:00
# 264475            2018 2018-02-03 00:40:00+00:00   0 days 16:41:00
# 264400            2018 2018-02-03 00:40:00+00:00   0 days 15:14:00
# 264272            2018 2018-02-03 00:40:00+00:00   0 days 14:12:00
# 264948            2018 2018-02-03 00:40:00+00:00   0 days 14:12:00
# 264309            2018 2018-02-03 00:40:00+00:00   0 days 13:49:00
# 264115            2018 2018-02-03 00:40:00+00:00   0 days 00:04:00
# 264276            2018 2018-02-03 00:40:00+00:00   0 days 00:04:00
# 264830            2018 2018-02-03 00:40:00+00:00   0 days 00:00:00
# 869186            2018 2018-02-03 00:40:00+00:00   0 days 00:00:00
#
#         prev_emerg  curr_inpatient  continued  first_ip
# 264480       False           False      False     False
# 264475       False           False       True     False
# 264400       False           False       True     False
# 264272        True           False       True     False
# 264948        True           False       True     False
# 264309        True           False       True     False
# 264115        True           False       True     False
# 264276        True           False       True     False
# 264830        True           False       True     False
# 869186        True            True       True      True

# %%
# 2 CSNs in keep_visits but not in change_pat 
change_pat[~change_pat['pat_enc_csn_id_coded'].isin(keep_visits['pat_enc_csn_id_coded'])]
# Out:
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 562177  JC1169632          131127789342   2015-10-31 05:38:00+00:00
# 767003  JC1928643          131164384313   2015-12-28 21:41:00+00:00
#
#         seq_num_in_enc  pat_class  base_pat_class_c  pat_lvl_of_care_c  \
# 562177               4  Inpatient               1.0                5.0
# 767003               2  Inpatient               1.0                5.0
#
#                                       pat_lv_of_care      event_type  \
# 562177  Acute Care (Assessment or intervention q4-8)  Patient Update
# 767003  Acute Care (Assessment or intervention q4-8)  Patient Update
#
#                 pat_service  department_id  effective_year  \
# 562177         Neurosurgery      2001002.0            2015
# 767003  Orthopaedic Surgery      2001002.0            2015
#
#                       admit_time time_before_admit  prev_emerg  \
# 562177 2015-10-31 05:38:00+00:00            0 days        True
# 767003 2015-12-28 21:41:00+00:00            0 days        True
#
#         curr_inpatient  continued  first_ip
# 562177            True       True      True
# 767003            True       True      True

# %%
# a correct case
adt_admit[adt_admit['pat_enc_csn_id_coded'] == 131062572931].sort_values('seq_num_in_enc').head()
# Out:
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 283731  JC1170548          131062572931   2015-01-01 18:40:00+00:00
# 283906  JC1170548          131062572931   2015-01-02 03:09:00+00:00
# 283445  JC1170548          131062572931   2015-01-02 03:09:00+00:00
# 283031  JC1170548          131062572931   2015-01-02 03:48:00+00:00
# 887228  JC1170548          131062572931   2015-01-02 03:48:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 283731               1  Emergency Services               3.0
# 283906               2  Emergency Services               NaN
# 283445               3  Emergency Services               NaN
# 283031               4  Emergency Services               NaN
# 887228               5           Inpatient               1.0
#
#         pat_lvl_of_care_c                            pat_lv_of_care  \
# 283731                NaN                                       NaN
# 283906                NaN                                       NaN
# 283445                NaN                                       NaN
# 283031                NaN                                       NaN
# 887228                6.0  Intermediate Care - With Cardiac Monitor
#
#           event_type                    pat_service  department_id  \
# 283731     Admission                      Emergency      2001002.0
# 283906  Transfer Out                      Emergency      2001002.0
# 283445   Transfer In                      Emergency      2001002.0
# 283031  Transfer Out                      Emergency      2001002.0
# 887228   Transfer In  General Medicine (University)      2000237.0
#
#         effective_year                admit_time time_before_admit  \
# 283731            2015 2015-01-02 03:48:00+00:00   0 days 09:08:00
# 283906            2015 2015-01-02 03:48:00+00:00   0 days 00:39:00
# 283445            2015 2015-01-02 03:48:00+00:00   0 days 00:39:00
# 283031            2015 2015-01-02 03:48:00+00:00   0 days 00:00:00
# 887228            2015 2015-01-02 03:48:00+00:00   0 days 00:00:00
#
#         prev_emerg  curr_inpatient  continued  first_ip
# 283731       False           False      False     False
# 283906        True           False       True     False
# 283445        True           False       True     False
# 283031        True           False       True     False
# 887228        True            True       True      True

# %%
# one of the 2 cases that were removed
# change_pat[change_pat['pat_enc_csn_id_coded'] == 131127789342].sort_values('seq_num_in_enc')
adt_admit[adt_admit['pat_enc_csn_id_coded'] == 131127789342].sort_values('seq_num_in_enc').head(4)
# Out:
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 334056  JC1169632          131127789342   2015-10-31 04:06:00+00:00
# 333938  JC1169632          131127789342   2015-10-31 04:06:00+00:00
# 333754  JC1169632          131127789342   2015-10-31 04:06:00+00:00
# 562177  JC1169632          131127789342   2015-10-31 05:38:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 334056               1  Emergency Services               3.0
# 333938               2  Emergency Services               NaN
# 333754               3  Emergency Services               NaN
# 562177               4           Inpatient               1.0
#
#         pat_lvl_of_care_c                                pat_lv_of_care  \
# 334056                NaN                                           NaN
# 333938                NaN                                           NaN
# 333754                NaN                                           NaN
# 562177                5.0  Acute Care (Assessment or intervention q4-8)
#
#             event_type   pat_service  department_id  effective_year  \
# 334056       Admission     Emergency      2001002.0            2015
# 333938    Transfer Out     Emergency      2001002.0            2015
# 333754     Transfer In     Emergency      2001002.0            2015
# 562177  Patient Update  Neurosurgery      2001002.0            2015
#
#                       admit_time time_before_admit  prev_emerg  \
# 334056 2015-10-31 05:38:00+00:00   0 days 01:32:00        True
# 333938 2015-10-31 05:38:00+00:00   0 days 01:32:00        True
# 333754 2015-10-31 05:38:00+00:00   0 days 01:32:00        True
# 562177 2015-10-31 05:38:00+00:00   0 days 00:00:00        True
#
#         curr_inpatient  continued  first_ip
# 334056           False      False     False
# 333938           False       True     False
# 333754           False       True     False
# 562177            True       True      True

# %%
change_pat[change_pat['pat_enc_csn_id_coded'] == 131127789342].sort_values('seq_num_in_enc').head(4)
# Out:
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 562177  JC1169632          131127789342   2015-10-31 05:38:00+00:00
#
#         seq_num_in_enc  pat_class  base_pat_class_c  pat_lvl_of_care_c  \
# 562177               4  Inpatient               1.0                5.0
#
#                                       pat_lv_of_care      event_type  \
# 562177  Acute Care (Assessment or intervention q4-8)  Patient Update
#
#          pat_service  department_id  effective_year                admit_time  \
# 562177  Neurosurgery      2001002.0            2015 2015-10-31 05:38:00+00:00
#
#        time_before_admit  prev_emerg  curr_inpatient  continued  first_ip
# 562177            0 days        True            True       True      True

# %%
# one of the 2 cases that were removed
adt_admit[adt_admit['pat_enc_csn_id_coded'] == 131164384313].sort_values('seq_num_in_enc').head(3)
# Out:
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 367939  JC1928643          131164384313   2015-12-28 17:49:00+00:00
# 767003  JC1928643          131164384313   2015-12-28 21:41:00+00:00
# 767049  JC1928643          131164384313   2015-12-29 00:03:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 367939               1  Emergency Services               3.0
# 767003               2           Inpatient               1.0
# 767049               3           Inpatient               NaN
#
#         pat_lvl_of_care_c                                pat_lv_of_care  \
# 367939                NaN                                           NaN
# 767003                5.0  Acute Care (Assessment or intervention q4-8)
# 767049                5.0  Acute Care (Assessment or intervention q4-8)
#
#             event_type          pat_service  department_id  effective_year  \
# 367939       Admission            Emergency      2001002.0            2015
# 767003  Patient Update  Orthopaedic Surgery      2001002.0            2015
# 767049    Transfer Out  Orthopaedic Surgery      2001002.0            2015
#
#                       admit_time time_before_admit  prev_emerg  \
# 367939 2015-12-28 21:41:00+00:00   0 days 03:52:00        True
# 767003 2015-12-28 21:41:00+00:00   0 days 00:00:00        True
# 767049 2015-12-28 21:41:00+00:00 -1 days +21:38:00       False
#
#         curr_inpatient  continued  first_ip
# 367939           False      False     False
# 767003            True       True      True
# 767049            True       True     False

# %%
change_pat[change_pat['pat_enc_csn_id_coded'] == 131062572931].sort_values('seq_num_in_enc').head(4)
# Out:
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 283731  JC1170548          131062572931   2015-01-01 18:40:00+00:00
# 887228  JC1170548          131062572931   2015-01-02 03:48:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 283731               1  Emergency Services               3.0
# 887228               5           Inpatient               1.0
#
#         pat_lvl_of_care_c                            pat_lv_of_care  \
# 283731                NaN                                       NaN
# 887228                6.0  Intermediate Care - With Cardiac Monitor
#
#          event_type                    pat_service  department_id  \
# 283731    Admission                      Emergency      2001002.0
# 887228  Transfer In  General Medicine (University)      2000237.0
#
#         effective_year                admit_time time_before_admit  \
# 283731            2015 2015-01-02 03:48:00+00:00   0 days 09:08:00
# 887228            2015 2015-01-02 03:48:00+00:00   0 days 00:00:00
#
#         prev_emerg  curr_inpatient  continued  first_ip
# 283731       False           False      False     False
# 887228        True            True       True      True

# %%
# by pass change_pat since the above 2 cases were drop at the change_pat = adt_admit.... and then keep_visits = change_pat...
keep_visits2 = adt_admit[(adt_admit.seq_num_in_enc == 1)]

print(keep_visits2.pat_enc_csn_id_coded.nunique())
keep_visits2.drop(hidecols, axis=1, errors='ignore').head()
# Out:
# 52532
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 283731  JC1170548          131062572931   2015-01-01 18:40:00+00:00
# 354402   JC913990          131062745090   2015-01-02 01:56:00+00:00
# 307756   JC529112          131062927111   2015-01-04 18:13:00+00:00
# 325130  JC1702404          131063006922   2015-01-06 09:04:00+00:00
# 284725   JC523028          131063022232   2015-01-03 14:51:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 283731               1  Emergency Services               3.0
# 354402               1  Emergency Services               3.0
# 307756               1  Emergency Services               3.0
# 325130               1  Emergency Services               3.0
# 284725               1  Emergency Services               3.0
#
#         pat_lvl_of_care_c pat_lv_of_care event_type pat_service  \
# 283731                NaN            NaN  Admission   Emergency
# 354402                NaN            NaN  Admission   Emergency
# 307756                NaN            NaN  Admission   Emergency
# 325130                NaN            NaN  Admission   Emergency
# 284725                NaN            NaN  Admission   Emergency
#
#         department_id  effective_year                admit_time  \
# 283731      2001002.0            2015 2015-01-02 03:48:00+00:00
# 354402      2001002.0            2015 2015-01-02 05:53:00+00:00
# 307756      2001002.0            2015 2015-01-05 03:20:00+00:00
# 325130      2001002.0            2015 2015-01-06 14:47:00+00:00
# 284725      2001002.0            2015 2015-01-03 21:24:00+00:00
#
#        time_before_admit  prev_emerg  curr_inpatient  continued  first_ip
# 283731   0 days 09:08:00       False           False      False     False
# 354402   0 days 03:57:00       False           False      False     False
# 307756   0 days 09:07:00       False           False      False     False
# 325130   0 days 05:43:00       False           False      False     False
# 284725   0 days 06:33:00       False           False      False     False

# %% [markdown]
# ### continue here keep_visits vs keep_visits2

# %%
# compute the time lapse between the ER visit and admission in hours
keep_visits['hours_before_admit'] = round(keep_visits.time_before_admit / np.timedelta64(1, 'h'), 2)
keep_visits.drop(hidecols, axis=1, errors='ignore').head(1)
# Out:
# <ipython-input-146-3db2c81cfe91>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keep_visits['hours_before_admit'] = round(keep_visits.time_before_admit / np.timedelta64(1, 'h'), 2)
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 283731  JC1170548          131062572931   2015-01-01 18:40:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 283731               1  Emergency Services               3.0
#
#         pat_lvl_of_care_c pat_lv_of_care event_type pat_service  \
# 283731                NaN            NaN  Admission   Emergency
#
#         department_id  effective_year                admit_time  \
# 283731      2001002.0            2015 2015-01-02 03:48:00+00:00
#
#        time_before_admit  prev_emerg  curr_inpatient  continued  first_ip  \
# 283731   0 days 09:08:00       False           False      False     False
#
#         hours_before_admit
# 283731                9.13

# %%
# compute the time lapse between the ER visit and admission in hours
keep_visits2['hours_before_admit'] = round(keep_visits2.time_before_admit / np.timedelta64(1, 'h'), 2)
keep_visits2.drop(hidecols, axis=1, errors='ignore').head(1)
# Out:
# <ipython-input-147-2876f95deaf8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keep_visits2['hours_before_admit'] = round(keep_visits2.time_before_admit / np.timedelta64(1, 'h'), 2)
#           anon_id  pat_enc_csn_id_coded effective_time_jittered_utc  \
# 283731  JC1170548          131062572931   2015-01-01 18:40:00+00:00
#
#         seq_num_in_enc           pat_class  base_pat_class_c  \
# 283731               1  Emergency Services               3.0
#
#         pat_lvl_of_care_c pat_lv_of_care event_type pat_service  \
# 283731                NaN            NaN  Admission   Emergency
#
#         department_id  effective_year                admit_time  \
# 283731      2001002.0            2015 2015-01-02 03:48:00+00:00
#
#        time_before_admit  prev_emerg  curr_inpatient  continued  first_ip  \
# 283731   0 days 09:08:00       False           False      False     False
#
#         hours_before_admit
# 283731                9.13

# %% [markdown]
# # Now look at time in ED

# %%
# print(keep_visits.columns)

print(keep_visits.hours_before_admit.describe())

keep_visits['hours_before_admit_quantile'] = pd.qcut(keep_visits.hours_before_admit, 10) # not working
# Out:
# count    52530.000000
# mean         4.810179
# std          6.415204
# min          0.020000
# 25%          2.300000
# 50%          3.500000
# 75%          5.250000
# max        190.430000
# Name: hours_before_admit, dtype: float64
# <ipython-input-148-5f0033c6c3f0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keep_visits['hours_before_admit_quantile'] = pd.qcut(keep_visits.hours_before_admit, 10)

# %%
# print(keep_visits2.columns)

# didn't change the summary stats
print(keep_visits2.hours_before_admit.describe())

# keep_visits2['hours_before_admit_quantile'] = pd.qcut(keep_visits2.hours_before_admit, 10)
# Out:
# count    52532.000000
# mean         4.810278
# std          6.415523
# min          0.020000
# 25%          2.300000
# 50%          3.500000
# 75%          5.250000
# max        190.430000
# Name: hours_before_admit, dtype: float64

# %% [markdown]
# ### check test set if available

# %% [raw]
# print(keep_visits.columns)
#
# # grab the year from the admit time
# keep_visits['test_set'] = keep_visits.pat_enc_csn_id_coded.isin(results.pat_enc_csn_id_coded)
#
# keep_visits.drop(hidecols, axis=1, errors='ignore').head()

# %% [raw]
# # visualize distribution
# p = sns.displot(keep_visits,
#                x='hours_before_admit',
#                 hue = 'test_set'
#                )
# p.fig.suptitle("Distribution of time spent in ED")
# p.fig.get_axes()[0].set_yscale('log')
# plt.show()

# %% [raw]
# # look at time spent in ED for train and test sets
# keep_visits.groupby('test_set').hours_before_admit.describe()

# %% [raw]
# keep_visits.drop(hidecols, axis=1, errors='ignore').head()

# %% [markdown]
# ### use keep_visits2 to make sure all cohort is included in here, keep_visits missed 2 patients

# %%
# save the hours before 
# final_visits = keep_visits[['pat_enc_csn_id_coded', 'hours_before_admit']]
final_visits = keep_visits2[['anon_id', 'pat_enc_csn_id_coded', 'effective_time_jittered_utc', 
                            'admit_time', 'time_before_admit', 'hours_before_admit']]
final_visits.rename({'hours_before_admit': 'hours_in_ed', 'effective_time_jittered_utc': 'ed_visit_time'}, axis=1, inplace=True)

print(final_visits.shape)
print(final_visits.pat_enc_csn_id_coded.nunique())

# final_visits.drop(hidecols, axis=1, errors='ignore').head()
# Out:
# (52532, 6)
# 52532
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
final_visits.head()
# Out:
#           anon_id  pat_enc_csn_id_coded             ed_visit_time  \
# 283731  JC1170548          131062572931 2015-01-01 18:40:00+00:00
# 354402   JC913990          131062745090 2015-01-02 01:56:00+00:00
# 307756   JC529112          131062927111 2015-01-04 18:13:00+00:00
# 325130  JC1702404          131063006922 2015-01-06 09:04:00+00:00
# 284725   JC523028          131063022232 2015-01-03 14:51:00+00:00
#
#                       admit_time time_before_admit  hours_in_ed
# 283731 2015-01-02 03:48:00+00:00   0 days 09:08:00         9.13
# 354402 2015-01-02 05:53:00+00:00   0 days 03:57:00         3.95
# 307756 2015-01-05 03:20:00+00:00   0 days 09:07:00         9.12
# 325130 2015-01-06 14:47:00+00:00   0 days 05:43:00         5.72
# 284725 2015-01-03 21:24:00+00:00   0 days 06:33:00         6.55

# %%
savefile = outdir + "/9_length_of_stay_in_ED.csv"

final_visits.to_csv(savefile, index=False)
